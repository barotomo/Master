# %%
import os
import pickle
import keras
import time

import numpy as np
import pandas as pd
import seaborn as sn
import random as rn
import tensorflow as tf
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.models import model_from_json
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop
from keras.optimizers import Adam

from keras.wrappers.scikit_learn import KerasClassifier
from keras.layers.core import Dense, Activation
from sklearn.model_selection import GridSearchCV

from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
def MLP_print_cmx(y_true, y_pred):
    labels = sorted(list(set(y_true)))
    cmx_data = confusion_matrix(y_true, y_pred, labels=labels)
    df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)
#     df_cmx.to_excel('Excel/doc2vec_headline_MLP.xlsx', encoding='UTF-16')
    plt.figure(figsize = (12,8))
    sn.heatmap(df_cmx, annot=True, fmt="d") ### ヒートマップの表示仕様
    plt.title("Confusion Matrix")
    plt.xlabel("predict_classes")
    plt.ylabel("true_classes")
    print('スポーツ : 0 / IT : 1 / 映画 : 2 / ライフ : 3')
    plt.show()

# %% [markdown]
# # dmpv

# %%
def MLP_dmpv(x_test, x_train, y_test, y_train, z_test, z_train, x_size, p):
    # MLPモデル構造を定義 --- (*5)
    MLP_model = Sequential()

    MLP_model.add(Dense(128, activation='relu', input_shape=(x_size,)))
    MLP_model.add(Dropout(0.2))
    MLP_model.add(Dense(128, activation='relu'))
    MLP_model.add(Dropout(0.2))
    MLP_model.add(Dense(128, activation='relu'))
    MLP_model.add(Dropout(0.2))
    MLP_model.add(Dense(nb_classes, activation='softmax'))

    # モデルをコンパイル --- (*6)
    MLP_model.compile(
        loss='categorical_crossentropy',
        optimizer=RMSprop(),
        metrics=['accuracy'])
    
    t1 = time.time()                 #　開始
    # 学習を実行 --- (*7)
    hist = MLP_model.fit(x_train, y_train,
              batch_size=128,
              epochs=50,
              verbose=1,
              validation_data=(x_test, y_test))
    t2 = time.time()                #　終了
    
   # モデルの保存
    MLP_model.save('./model/dmpv_model_'+str(p)+'.hdf5')
    
    # モデルのロード
    model = load_model('./model/dmpv_model_'+str(p)+'.hdf5')
    #  混同行列
    predict_classes = model.predict_classes(x_test[1:10000]) ### 予測したラベルを取得
    true_classes = np.argmax(y_test[1:10000], 1) ### 実際のラベルを取得

    # 評価する ---(*8)
    score = model.evaluate(x_test, y_test, verbose=1)
    print('\n')
    print("正解率=", score[1], 'loss=', score[0])

    #  適応率, 再現率, F値
    rep = metrics.classification_report(true_classes, predict_classes)
    print(rep)

    # 学習の様子をグラフへ描画 --- (*10)
    # Accuracy
    plt.figure(figsize=(20, 5)) # figureの縦横の大きさ
    plt.subplot(1,2,1)
    plt.plot(hist.history['acc'])
    plt.plot(hist.history['val_acc'])
    plt.title('Accuracy')
    plt.legend(['train', 'test'], loc='upper left')
    plt.grid()

    # Loss
    plt.subplot(1,2,2)
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('Loss')
    plt.legend(['train', 'test'], loc='upper left')
    plt.grid()

    MLP_print_cmx(true_classes, predict_classes)

    # 経過時間を表示
    elapsed_time = t2-t1
    print(f"処理時間：{elapsed_time}"+"[s]")

    LABELS = ["スポーツ", "IT", "映画", "ライフ"]
    A=[]
    B=[]
    C=[]
    D=[]
    for i, j, k in zip(x_test, y_test, z_test):
        pre = model.predict(np.array([i]))[0]
        n = pre.argmax()
        l=np.where(j==1.0)
        if LABELS[n]!=LABELS[l[0][0]]:
            A.append(LABELS[n])
            B.append(pre[n])
            C.append(LABELS[l[0][0]])
            D.append(k)

    df=pd.DataFrame({'text':D,
                                     'true_label':C, 
                                    'pre_label':A,
                                    'prediction':B}
                                   )

    #     df.to_excel('Excel/TF-IDF_MLP_'+str(p)+'.xlsx', encoding='UTF-16')
    display(df)

# %%
# データのロード
data_c=pickle.load(open('/Users/Baron/Document/text_mining/Data/pickle/Doc2Vec/Headline/d2v_headline_dmpv.pickle', "rb"))

z_c = data_c[0]   # 内容
y_c = data_c[1]   # ラベル
x_c = data_c[2]   # 特徴量

kf = KFold(n_splits=5, shuffle=True, random_state=0)
nb_classes = 4
# ラベルデータをone-hotベクトルに直す --- (*3)
y_c = keras.utils.np_utils.to_categorical(y_c, nb_classes)

# データの次元数
x_size = x_c[0].shape[0]
y_size = y_c[0].shape[0]

A_index_c=[]
B_index_c=[]
C_index_c=[]
D_index_c=[]
E_index_c=[]
F_index_c=[]

# 交差検証
for train, test in kf.split(x_c):
    A_c=np.empty((0,x_size), int)
    B_c=np.empty((0,x_size), int)
    C_c=np.empty((0,y_size), int)
    D_c=np.empty((0,y_size), int)
    E_c = []
    F_c = []
    for i in test:
        A_c = np.append(A_c, [x_c[i]], axis=0)           # x_test
        C_c = np.append(C_c, [y_c[i]], axis=0)           # y_test
        E_c.append(z_c[i])                                     # z_test
    A_index_c.append(A_c)
    C_index_c.append(C_c)
    E_index_c.append(E_c)
    for j in train:
        B_c = np.append(B_c, [x_c[j]], axis=0)            # x_train
        D_c = np.append(D_c, [y_c[j]], axis=0)           # y_train
        F_c.append(z_c[j])                                      # z_train
    B_index_c.append(B_c)
    D_index_c.append(D_c)
    F_index_c.append(F_c)

# %%
MLP_dmpv(A_index_c[0], B_index_c[0], C_index_c[0], D_index_c[0], E_index_c[0], F_index_c[0], x_size, p=0)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0318 22:51:35.059612 140735485961088 deprecation_wrapper.py:119] From /Users/Baron/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0318 22:51:35.116849 140735485961088 deprecation_wrapper.py:119] From /Users/Baron/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0318 22:51:35.135902 140735485961088 deprecation_wrapper.py:119] From /Users/Baron/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0318 22:51:35.199104 140735485961088 deprecation_wrapper.py:119] From /Users/Baron/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0318 22:51:35.215319 140735485961088 deprecation.py:506] From /Users/Baron/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0318 22:51:35.382379 140735485961088 deprecation_wrapper.py:119] From /Users/Baron/anaconda3/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0318 22:51:35.396064 140735485961088 deprecation_wrapper.py:119] From /Users/Baron/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0318 22:51:35.534690 140735485961088 deprecation.py:323] From /Users/Baron/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 2806 samples, validate on 702 samples
# Epoch 1/50
# 2806/2806 [==============================] - 1s 299us/step - loss: 1.1413 - acc: 0.5292 - val_loss: 0.8088 - val_acc: 0.7593
# Epoch 2/50
# 2806/2806 [==============================] - 0s 36us/step - loss: 0.7848 - acc: 0.7259 - val_loss: 0.6462 - val_acc: 0.7721
# Epoch 3/50
# 2806/2806 [==============================] - 0s 35us/step - loss: 0.6713 - acc: 0.7594 - val_loss: 0.5787 - val_acc: 0.8048
# Epoch 4/50
# 2806/2806 [==============================] - 0s 34us/step - loss: 0.5914 - acc: 0.7965 - val_loss: 0.5325 - val_acc: 0.8262
# Epoch 5/50
# 2806/2806 [==============================] - 0s 33us/step - loss: 0.5402 - acc: 0.8115 - val_loss: 0.5140 - val_acc: 0.8276
# Epoch 6/50
# 2806/2806 [==============================] - 0s 34us/step - loss: 0
50
# 2806/2806 [==============================] - 0s 34us/step - loss: 0.0274 - acc: 0.9914 - val_loss: 0.9976 - val_acc: 0.8305
# Epoch 37/50
# 2806/2806 [==============================] - 0s 36us/step - loss: 0.0254 - acc: 0.9932 - val_loss: 0.9897 - val_acc: 0.8362
# Epoch 38/50
# 2806/2806 [==============================] - 0s 35us/step - loss: 0.0246 - acc: 0.9925 - val_loss: 1.0202 - val_acc: 0.8433
# Epoch 39/50
# 2806/2806 [==============================] - ETA: 0s - loss: 0.0322 - acc: 0.992 - 0s 35us/step - loss: 0.0274 - acc: 0.9932 - val_loss: 1.0169 - val_acc: 0.8476
# Epoch 40/50
# 2806/2806 [==============================] - 0s 34us/step - loss: 0.0206 - acc: 0.9936 - val_loss: 1.0877 - val_acc: 0.8390
# Epoch 41/50
# 2806/2806 [==============================] - 0s 35us/step - loss: 0.0258 - acc: 0.9929 - val_loss: 1.0298 - val_acc: 0.8433
# Epoch 42/50
# 2806/2806 [==============================] - 0s 35us/step - loss: 0.0263 - acc: 0.9918 - val_loss: 1.0677 - val_acc: 0.8390
# Epoch 43/50
# 2806/2806 [==============================] - 0s 34us/step - loss: 0.0208 - acc: 0.9922 - val_loss: 1.0535 - val_acc: 0.8362
# Epoch 44/50
# 2806/2806 [==============================] - 0s 35us/step - loss: 0.0129 - acc: 0.9964 - val_loss: 1.0570 - val_acc: 0.8462
# Epoch 45/50
# 2806/2806 [==============================] - 0s 35us/step - loss: 0.0167 - acc: 0.9957 - val_loss: 1.0548 - val_acc: 0.8433
# Epoch 46/50
# 2806/2806 [==============================] - 0s 35us/step - loss: 0.0190 - acc: 0.9954 - val_loss: 1.0782 - val_acc: 0.8533
# Epoch 47/50
# 2806/2806 [==============================] - 0s 35us/step - loss: 0.0176 - acc: 0.9943 - val_loss: 1.1125 - val_acc: 0.8405
# Epoch 48/50
# 2806/2806 [==============================] - 0s 34us/step - loss: 0.0175 - acc: 0.9957 - val_loss: 1.1062 - val_acc: 0.8419
# Epoch 49/50
# 2806/2806 [==============================] - 0s 36us/step - loss: 0.0182 - acc: 0.9929 - val_loss: 1.1458 - val_acc: 0.8476
# Epoch 50/50
# 2806/2806 [==============================] - 0s 35us/step - loss: 0.0201 - acc: 0.9954 - val_loss: 1.1530 - val_acc: 0.8419
# 702/702 [==============================] - 0s 139us/step
#
#
# 正解率= 0.8418803423897833 loss= 1.1530497532624464
#               precision    recall  f1-score   support
#
#            0       0.83      0.87      0.85       193
#            1       0.84      0.93      0.88       160
#            2       0.83      0.79      0.81       170
#            3       0.87      0.78      0.82       178
#
#     accuracy                           0.84       701
#    macro avg       0.84      0.84      0.84       701
# weighted avg       0.84      0.84      0.84       701
#
# スポーツ : 0 / IT : 1 / 映画 : 2 / ライフ : 3
# 処理時間：6.423403024673462[s]
#                                                   text true_label pre_label  \
# 0      DeNA春田真会長、プロ野球参入の理由は「12個しかないアセットを会社で持つ重みがある」       スポーツ        IT
# 1                  “史上最低の外国人選手”が母国でツイッター更新、ファンの怒りは増幅       スポーツ        映画
# 2                   「広島のせいにするな」浦和・槙野智章のインタビューがひんしゅく        スポーツ        映画
# 3             【Sports Watch】F・マリノス所属選手がツイッターで意味深発言!?       スポーツ       ライフ
# 4                  【Sports Watch】国母の服装問題に、山本KID「くだらん」       スポーツ        映画
# 5         【Sports Watch】宮崎大輔に、妻は“朝まで遊んで。スポーツ選手ですよ”       スポーツ       ライフ
# 6               【Sports Watch】松坂大輔「もう勝ったと思って寝るわ」→大逆転負け       スポーツ        映画
# 7                【Sports Watch】泉浩と熱愛報道、末永遥「マスコミって恐ろしい」       スポーツ        映画
# 8     【Sports Watch】高所得者が考える「理想の部下」に有名アスリートが軒並みランクイン       スポーツ        IT
# 9      【Sports Watch】高橋尚 “（カットは）ピッチャーだけで9人。明日は我が身”       スポーツ        映画
# 10       【Sports Watch】鬼嫁・新山千春“ゴミが私の手にやってくるって考えられない”       スポーツ       ライフ
# 11                      ナイナイ矢部の“裏やべっちF.C.” 「松井大輔を使え！」       スポーツ       ライフ
# 12                  フェンシング・太田の無茶ぶりに三宅がギャグを披露するも——       スポーツ        IT
# 13                      マラソン・藤原新、躍進のきっかけは“カリスマ美女”との出会い       スポーツ        IT
# 14                         上々の投球内容も、ダルビッシュが抱える課題とは？       スポーツ        IT
# 15                                  中田英寿も認めた天才MFが現役引退       スポーツ        映画
# 16                   北京五輪でまさかの失策、G.G.佐藤の妻「一言“死にたい”って」       スポーツ        映画
# 17                         北島康介、獲得した銀メダルに「重さは確かに一番重い」       スポーツ        映画
# 18                      新記録でロンドンに乗り込む“バタフライの女王”加藤ゆか       スポーツ        映画
# 19                 日ハム・大嶋匠、連日の活躍にも「少年野球以来なので、野球をするのは」       スポーツ        映画
# 20                 曙の恐るべき飲みっぷり。一晩で使った飲み代は「1000万くらい」       スポーツ        IT
# 21                        楽天・岩隈の禁断不倫愛——、お相手は“妻の義理の妹”!?       スポーツ       ライフ
# 22                      止まぬ紗栄子批判も “養育費月1000万円要求”の信憑性は？       スポーツ        映画
# 23                             澤穂希を襲った「良性発作性頭位めまい症」とは？       スポーツ       ライフ
# 24                  長友が語る本田圭佑の面白さ「分かってないんです、周りの反応が」       スポーツ       ライフ
# 25                            3姉妹の成長を瞬間的に捉えた妖艶で可憐な世界観         IT      スポーツ
# 26              iPhoneアプリを子どもが勝手に使えないようにする【知っ得！虎の巻】         IT       ライフ
# 27            nasneが再出発！出荷延期中だったSCEのnasneの再出荷が決定される         IT      スポーツ
# 28   ゲームサウンドが聴き放題！ 24時間無料でゲームサウンドが聴けるSQUARE-...         IT      スポーツ
# 29               ジメっとした気分を吹き飛ばせ！いまが見ごろ、鎌倉の紫陽花写真の数々         IT        映画
# ..                                                 ...        ...       ...
# 81         アナ スイ コスメティックスが本気を出した!? 噂の新製品＆限定品をさっそくチェック        ライフ        IT
# 82             オトナ女子たちの圧倒的支持をうけ、ドラマ10『はつ恋』の一挙再放送が決定！        ライフ        IT
# 83                             シングル女性が陥りやすい友達親子リスクとは        ライフ      スポーツ
# 84   スイーツ番長とフードコーディーネーターが推奨！「スイーツをより楽しむコツは、“ウーロン...        ライフ        IT
# 85                                        セフレと彼女の違いとは?        ライフ      スポーツ
# 86                                バイキングという食文化をどう思う？        ライフ      スポーツ
# 87                             今の時代でも健在！「SNS嫌い」男性のいい分        ライフ        IT
# 88                  今年のクリスマス、リムジンのお出迎えでセレブな1日はいかが？        ライフ        映画
# 89                            冬の乾燥肌に朗報？タモリ式入浴法にチャレンジ！        ライフ        IT
# 90                                         処世術はSMに学べ！        ライフ      スポーツ
# 91                  古き良き日本文化を伝承する「お正月ニッポンプロジェクト」に注目        ライフ      スポーツ
# 92                                同世代の長谷川理恵の破局について思うこと        ライフ      スポーツ
# 93   同世代女性の心をガッチリ掴んだ「セックス・アンド・ザ・シティ2 ［ザ・ムービー］...        ライフ        映画
# 94                                   女を勇者に変える！？ 出産のホント        ライフ      スポーツ
# 95                            女性にも多い痔主さん！相談しにくい「おしり」の話        ライフ        映画
# 96                     手相占い体験談！ 結婚線ができた！ 女難の相が当たった？        ライフ        映画
# 97                          放っておけない！長年「好きな人がいない」理由とは？        ライフ      スポーツ
# 98                            日本←→韓国ドラマのリメイク作品、どう思う？        ライフ        映画
# 99     日本の大切な文化“お正月”について学び、情報発信をする「お正月キュレーター候補生」を大募集！        ライフ        映画
# 100                                 次のバケーションはトルコに決まり！        ライフ      スポーツ
# 101           沖縄時間で癒してくれるスペシャルサイト「OKINAHOURS」がオープン        ライフ        IT
# 102                           流行は回帰する……ブログが再び面白い理由        ライフ      スポーツ
# 103                    猛暑が後押し!? アラフォー女性の生足増加とストッキング感        ライフ        IT
# 104                             現役ホステスに聞く、一番人気のホステスとは？        ライフ        映画
# 105                          節電しながらムーディーな照明で夜を楽しもう！        ライフ      スポーツ
# 106                           花粉シーズン到来前にビフィズス菌の新習慣！        ライフ        映画
# 107                         読んでみる？描いてみる？大人の女性を癒す絵本の魅力        ライフ        IT
# 108                              貧困女子とかマジ勘弁！ 事実婚という選択        ライフ      スポーツ
# 109                                   霊柩車を見ると親指を隠しますか？        ライフ        映画
# 110                   驚異の保水力を持ったプロテオグリカンで夏こそ肌に潤いを！！        ライフ        映画
#
#      prediction
# 0      0.999995
# 1      0.608710
# 2      0.527117
# 3      0.936817
# 4      0.999886
# 5      0.999988
# 6      0.612784
# 7      0.549652
# 8      0.999736
# 9      0.999988
# 10     0.999998
# 11     0.999023
# 12     0.999989
# 13     1.000000
# 14     0.654816
# 15     0.515400
# 16     0.990454
# 17     0.985032
# 18     0.912968
# 19     0.661602
# 20     0.995248
# 21     0.999932
# 22     0.999980
# 23     0.942154
# 24     0.533902
# 25     0.999939
# 26     0.993584
# 27     0.838551
# 28     1.000000
# 29     0.989391
# ..          ...
# 81     0.999968
# 82     0.996918
# 83     0.985364
# 84     0.995309
# 85     0.909124
# 86     0.904827
# 87     0.977677
# 88     0.843729
# 89     1.000000
# 90     0.999647
# 91     0.987826
# 92     0.912580
# 93     0.999288
# 94     0.986340
# 95     0.998474
# 96     0.949247
# 97     0.802823
# 98     0.877237
# 99     0.838160
# 100    0.999626
# 101    0.999985
# 102    0.988037
# 103    0.680745
# 104    0.719277
# 105    0.999871
# 106    0.530325
# 107    0.685866
# 108    0.996075
# 109    0.956245
# 110    0.999976
#
# [111 rows x 4 columns]

# %%
MLP_dmpv(A_index_c[1], B_index_c[1], C_index_c[1], D_index_c[1], E_index_c[1], F_index_c[1], x_size, p=1)
# Out:
# Train on 2806 samples, validate on 702 samples
# Epoch 1/50
# 2806/2806 [==============================] - 1s 220us/step - loss: 1.1479 - acc: 0.5264 - val_loss: 0.8961 - val_acc: 0.7123
# Epoch 2/50
# 2806/2806 [==============================] - 0s 38us/step - loss: 0.8146 - acc: 0.6942 - val_loss: 0.6981 - val_acc: 0.7422
# Epoch 3/50
# 2806/2806 [==============================] - 0s 40us/step - loss: 0.6683 - acc: 0.7680 - val_loss: 0.6077 - val_acc: 0.7906
# Epoch 4/50
# 2806/2806 [==============================] - 0s 36us/step - loss: 0
50
# 2806/2806 [==============================] - 0s 35us/step - loss: 0.0230 - acc: 0.9932 - val_loss: 1.0205 - val_acc: 0.8205
# Epoch 38/50
# 2806/2806 [==============================] - 0s 38us/step - loss: 0.0260 - acc: 0.9907 - val_loss: 1.0970 - val_acc: 0.8234
# Epoch 39/50
# 2806/2806 [==============================] - 0s 38us/step - loss: 0.0266 - acc: 0.9925 - val_loss: 1.0644 - val_acc: 0.8177
# Epoch 40/50
# 2806/2806 [==============================] - 0s 40us/step - loss: 0.0235 - acc: 0.9943 - val_loss: 1.1304 - val_acc: 0.8177
# Epoch 41/50
# 2806/2806 [==============================] - 0s 38us/step - loss: 0.0244 - acc: 0.9925 - val_loss: 1.2006 - val_acc: 0.8091
# Epoch 42/50
# 2806/2806 [==============================] - 0s 37us/step - loss: 0.0224 - acc: 0.9922 - val_loss: 1.1092 - val_acc: 0.8219
# Epoch 43/50
# 2806/2806 [==============================] - 0s 35us/step - loss: 0.0178 - acc: 0.9950 - val_loss: 1.1668 - val_acc: 0.8191
# Epoch 44/50
# 2806/2806 [==============================] - 0s 35us/step - loss: 0.0287 - acc: 0.9914 - val_loss: 1.1524 - val_acc: 0.8148
# Epoch 45/50
# 2806/2806 [==============================] - 0s 35us/step - loss: 0.0170 - acc: 0.9943 - val_loss: 1.1099 - val_acc: 0.8291
# Epoch 46/50
# 2806/2806 [==============================] - 0s 43us/step - loss: 0.0105 - acc: 0.9968 - val_loss: 1.1795 - val_acc: 0.8191
# Epoch 47/50
# 2806/2806 [==============================] - 0s 55us/step - loss: 0.0327 - acc: 0.9929 - val_loss: 1.1786 - val_acc: 0.8205
# Epoch 48/50
# 2806/2806 [==============================] - 0s 49us/step - loss: 0.0165 - acc: 0.9961 - val_loss: 1.1068 - val_acc: 0.8333
# Epoch 49/50
# 2806/2806 [==============================] - 0s 52us/step - loss: 0.0177 - acc: 0.9957 - val_loss: 1.0993 - val_acc: 0.8319
# Epoch 50/50
# 2806/2806 [==============================] - 0s 43us/step - loss: 0.0144 - acc: 0.9968 - val_loss: 1.1838 - val_acc: 0.8291
# 702/702 [==============================] - 0s 279us/step
#
#
# 正解率= 0.8290598282107601 loss= 1.1837718464020226
#               precision    recall  f1-score   support
#
#            0       0.85      0.80      0.82       179
#            1       0.92      0.84      0.88       193
#            2       0.74      0.81      0.78       169
#            3       0.81      0.86      0.84       160
#
#     accuracy                           0.83       701
#    macro avg       0.83      0.83      0.83       701
# weighted avg       0.83      0.83      0.83       701
#
# スポーツ : 0 / IT : 1 / 映画 : 2 / ライフ : 3
# 処理時間：6.278085947036743[s]
#                                                  text true_label pre_label  \
# 0               “日本の心臓”遠藤保仁の凄すぎるプレー、日本を救った1本のパスとは？       スポーツ        IT
# 1                            “異常な時代”の終焉、レーザーレーサーの今とは       スポーツ        IT
# 2                      「なぜ足で止めようと」自分の車に轢かれ今季絶望の選手         スポーツ       ライフ
# 3                  「泣いてんのかこれ」、“熱すぎる”アナウンサーが劇的結末に大興奮       スポーツ        映画
# 4              【Sports Watch】ヨナのミスジャンプに加点、集まる疑問視する声       スポーツ        映画
# 5                      【Sports Watch】上田桃子「この度、結婚致します」       スポーツ       ライフ
# 6      【Sports Watch】中田英、日本惜敗も「勝ちにいく姿勢が見えたっていうのは大きい」       スポーツ        映画
# 7       【Sports Watch】仕事中、サッチーから“もうやめて帰ってこい”と言われるノムさん       スポーツ       ライフ
# 8       【Sports Watch】全治6カ月、代表入りが危ぶまれる丸山にかけた澤の言葉とは？       スポーツ        IT
# 102           みんなで飾って幸せを……、マジカルツリーが新たなるパワースポットに？        ライフ        IT
# 103           スマートで美しい“サイフ美人”はロンドンっ娘！ その理由はカードにあり！        ライフ        映画
# 104                         ダイエット不要！ぽっちゃり系の時代が到来！？        ライフ        IT
# 105                            一気に好感度が上がる彼女選び・妻選び        ライフ      スポーツ
# 106                            不満だらけのランチタイム、ココを変えたい！        ライフ        映画
# 107                                不運が重なるのはなぜ？独女の嘆き        ライフ        映画
# 108                 女どうしでもなかなか聞けない！ アンダーヘア、どうしてる？        ライフ      スポーツ
# 109                             女子が嬉しいホメ言葉、嬉しくないホメ言葉        ライフ      スポーツ
# 110                       家に帰ったらダメ人間化!? 人には見せられない私の姿        ライフ        映画
# 111                                恋人不在多数、恋愛低体温症の独女たち        ライフ        映画
# 112                             最悪逮捕も!? 不正アクセス禁止法を学ぶ        ライフ      スポーツ
# 113                              災害ボランティア体験者が感じたこと        ライフ        映画
# 114                   独女も共感!? “イタい歌詞”で注目を浴びる奥 華子の世界        ライフ        IT
# 115              独女的書籍紹介『ブータン、これでいいのだ』 新潮社 御手洗瑞子:著        ライフ        映画
# 116                     生活レベルが丸見え? ブログの料理ネタには要注意！        ライフ        IT
# 117                               税金を払うのは私たちなんですけど！        ライフ        映画
# 118               続ける? 使い分ける? Facebook、Twitter……SNSの今        ライフ        IT
# 119                                 １回限りの関係で終わってしまう女        ライフ      スポーツ
#
#      prediction
# 0      0.999277
# 1      0.842827
# 2      0.561546
# 3      0.988249
# 4      0.999995
# 5      0.789601
# 6      0.999839
# 7      0.999997
# 8      0.934480
# 9      0.986820
# 10     0.889169
# 11     0.626932
# 12     0.957978
# 13     0.718258
# 14     0.996826
# 15     1.000000
# 16     0.999990
# 17     0.926325
# 18     0.677076
# 19     0.997094
# 20     0.957978
# 21     0.995564
# 22     0.762266
# 23     0.792233
# 24     0.839218
# 25     0.999880
# 26     0.467172
# 27     0.981283
# 28     0.999999
# 29     0.999927
# ..          ...
# 90     0.958688
# 91     0.982518
# 92     0.999677
# 93     0.935917
# 94     0.943787
# 95     0.634638
# 96     0.999728
# 97     0.999094
# 98     0.999964
# 99     0.980530
# 100    1.000000
# 101    0.997925
# 102    0.975770
# 103    0.996944
# 104    0.980376
# 105    0.500290
# 106    0.988410
# 107    0.809088
# 108    0.999676
# 109    0.779360
# 110    0.559120
# 111    0.984350
# 112    0.998067
# 113    0.930816
# 114    0.950708
# 115    0.991216
# 116    0.993700
# 117    0.961473
# 118    0.861172
# 119    0.996642
#
# [120 rows x 4 columns]

# %%
MLP_dmpv(A_index_c[2], B_index_c[2], C_index_c[2], D_index_c[2], E_index_c[2], F_index_c[2], x_size, p=2)
# Out:
# Train on 2806 samples, validate on 702 samples
# Epoch 1/50
# 2806/2806 [==============================] - 1s 298us/step - loss: 1.1454 - acc: 0.5046 - val_loss: 0.8652 - val_acc: 0.7179
# Epoch 2/50
# 2806/2806 [==============================] - 0s 35us/step - loss: 0.8140 - acc: 0.7081 - val_loss: 0.7142 - val_acc: 0.7493
# Epoch 3/50
# 2806/2806 [==============================] - 0s 35us/step - loss: 0
# 112                                  今後はどうなる？ 結納という儀式        ライフ        IT
# 113                             仕切り屋女子vs他力本願女子それぞれの憂鬱        ライフ      スポーツ
# 114                       夏本番だからこそ油断は禁物！ムダ毛処理を見逃すな！！        ライフ        IT
# 115                           大人女子がスカートの下に秘めるべきものとは？        ライフ        IT
# 116               意外と知らない我が家のルーツ！ 新年会でご先祖様トークはいかが？        ライフ        IT
# 117                          懐かしさと勢いには要注意！？ 同窓会での恋愛事情        ライフ      スポーツ
# 118          映画を観ながらダイエット！「映画ヨガ」をカンタンに学べる無料動画が公開中        ライフ        映画
# 119                               本日はお日柄もよく、結婚式は大安吉日に？        ライフ        IT
# 120                          欲しくなったときが適齢期？ わたしたちの高齢出産        ライフ        IT
# 121               正直ちょっと面倒!?な 女子会の幹事をラクラクこなせる新サービスとは？        ライフ      スポーツ
# 122                            気になる妊娠のこと「つわりって辛いですか？」        ライフ        IT
# 123                                独女がついつい見栄を張ってしまうとき        ライフ        映画
# 124                                 独女のTwitter、意外な楽しみ方        ライフ      スポーツ
# 125                        目指すはローラ!? 誰でもタメ口キャラは独女に有効か        ライフ        映画
# 126                結婚は“相手”より“タイミング”の問題？「ラブ・ダイアリーズ」        ライフ      スポーツ
# 127                              給湯室で抹茶を楽しむ『給湯流茶道』とは？        ライフ      スポーツ
# 128                                    話題のタニタ食堂へ行ってみた！        ライフ        映画
# 129                      話題の二股騒動……あなたはしたこと、されたことありますか？        ライフ        映画
# 130                            赤裸々な女の生態を描く「祝女」が帰ってくる！        ライフ        映画
# 131                               過剰なラブリーは男たちを戸惑わせる!?        ライフ        映画
# 132  高樹千佳子らがビオプレーン4姉妹として登場！ 「ダノンビオ」ヨーグルトプレーン...        ライフ      スポーツ
#
#      prediction
# 0      0.798077
# 1      0.782299
# 2      0.926559
# 3      0.944603
# 4      0.991619
# 5      0.999092
# 6      0.968154
# 7      0.879753
# 8      0.889775
# 9      0.998903
# 10     0.854238
# 11     0.999401
# 12     0.916269
# 13     0.471096
# 14     0.996752
# 15     0.993643
# 16     0.664634
# 17     0.842616
# 18     0.998527
# 19     0.987694
# 20     0.888454
# 21     0.696589
# 22     0.998528
# 23     0.869149
# 24     0.993232
# 25     0.547584
# 26     0.984069
# 27     0.531668
# 28     1.000000
# 29     0.995111
# ..          ...
# 103    0.999972
# 104    0.572907
# 105    0.983130
# 106    0.984169
# 107    0.632039
# 108    0.791073
# 109    0.458175
# 110    0.844347
# 111    0.868381
# 112    0.999874
# 113    1.000000
# 114    0.999999
# 115    0.476081
# 116    1.000000
# 117    0.867945
# 118    1.000000
# 119    0.999642
# 120    0.976100
# 121    0.999983
# 122    0.676446
# 123    0.785851
# 124    0.985094
# 125    0.818166
# 126    0.998459
# 127    1.000000
# 128    0.846866
# 129    0.762348
# 130    0.616802
# 131    0.846620
# 132    0.792164
#
# [133 rows x 4 columns]

# %%
MLP_dmpv(A_index_c[3], B_index_c[3], C_index_c[3], D_index_c[3], E_index_c[3], F_index_c[3], x_size, p=3)
50
# 2807/2807 [==============================] - 0s 36us/step - loss: 0.0145 - acc: 0.9939 - val_loss: 1.3689 - val_acc: 0.8017
# 701/701 [==============================] - 0s 365us/step
#
#
# 正解率= 0.8017118405683574 loss= 1.3688628474587892
#               precision    recall  f1-score   support
#
#            0       0.81      0.79      0.80       176
#            1       0.77      0.88      0.82       155
#            2       0.81      0.76      0.78       196
#            3       0.82      0.79      0.80       173
#
#     accuracy                           0.80       700
#    macro avg       0.80      0.80      0.80       700
# weighted avg       0.80      0.80      0.80       700
#
# スポーツ : 0 / IT : 1 / 映画 : 2 / ライフ : 3
# 処理時間：7.1395509243011475[s]
#                                                   text true_label pre_label  \
# 0                         「妖精・浅尾」に引けを取らない美貌の新パートナーとは？       スポーツ        IT
# 1                             「笑わない女王」女子柔道・中村美里の笑わないワケ       スポーツ        映画
# 2            【Sports Watch】W杯ツアー業者が音信不通、被害額は1500万円超!?       スポーツ       ライフ
# 3                【Sports Watch】“満塁男”駒田氏が、最近の虐待事件に怒り露わ       スポーツ        IT
# 4               【Sports Watch】“美人すぎる市議”、ジェイロックと契約を締結       スポーツ        IT
# 5         【Sports Watch】なでしこジャパンの体質 「苦しい時ほど無理くり笑う」       スポーツ        映画
# 6        【Sports Watch】ゴン中山、退屈なゲームに「日本戦じゃなきゃ、寝てますね」       スポーツ        IT
# 7                    【Sports Watch】ショック、“鬼軍曹”山本小鉄氏が急逝       スポーツ        IT
# 8            【Sports Watch】ナイナイ矢部、「優勝はスペインって言ったでしょ？」       スポーツ       ライフ
# 9       【Sports Watch】ミニスカ姿に苦情？ 山岸舞彩アナに「肩さんもいよいよメジャー」       スポーツ        映画
# 10   【Sports Watch】ロンドン五輪まで一年、潮田“オリンピックの悔しさは、オリン...       スポーツ        IT
# 11                 【Sports Watch】原発事故で危機に立たされた女子アスリート       スポーツ        映画
# 12        【Sports Watch】大活躍の日ハム・中田翔に、野村克也氏「納得できないんだ」       スポーツ        IT
# 13              【Sports Watch】岡田監督、高校時代は女性用パンティーを着用!?       スポーツ       ライフ
# 14      【Sports Watch】巨人の助っ人補強に、ノムさん「外人担当スカウト、しっかり見ろよ」       スポーツ        映画
# 15    【Sports Watch】松井大輔＆ローサの結婚。芸能レポーターも「全く知りませんでした」       スポーツ       ライフ
# 16   【Sports Watch】格下相手に2試合連続スコアレスドローも、新システムは「やめる必...       スポーツ        IT
# 17              【Sports Watch】超美形の女子大生ボクサーがロンドンを目指す       スポーツ       ライフ
# 18   【Sports Watch】逆境の連続、なでしこジャパンの優勝に川澄・父「信じてあけ...       スポーツ        映画
# 19                       スター性抜群、次代を担う“超美少女スケーター”今井遥に注目       スポーツ        映画
# 20          ダル実戦デビューに「あれが本物のダルビッシュだと思ったら大きな間違い」       スポーツ       ライフ
# 21                    ディーン元気、やり投げの秘密 「あり得ないところまでいく」       スポーツ        IT
# 22                  ボールが顔面を直撃した石井一久＆中村剛也、壮絶エピソード語る       スポーツ        映画
# 23               上原、悪夢のプレーオフ初登板に、ノムさん「自分を見失っているね、完全に」       スポーツ        映画
# 2      0.995155
# 3      0.999982
# 4      0.710983
# 5      0.648063
# 6      0.963450
# 7      0.940652
# 8      0.949845
# 9      0.993920
# 10     0.999647
# 11     0.493960
# 12     0.845874
# 13     0.912448
# 14     0.867385
# 15     0.997091
# 16     0.748893
# 17     0.497072
# 18     0.999729
# 19     0.542977
# 20     0.837038
# 21     0.943264
# 22     0.999997
# 23     0.973572
# 24     0.999829
# 25     0.666140
# 26     0.657062
# 27     0.900106
# 28     0.947541
# 29     0.999940
# ..          ...
# 109    0.910367
# 110    0.809872
# 111    1.000000
# 112    0.987493
# 113    0.999983
# 114    0.999709
# 115    0.735552
# 116    0.656580
# 117    0.931547
# 118    0.997932
# 119    0.999223
# 120    0.520079
# 121    0.999931
# 122    0.987899
# 123    0.999967
# 124    0.998159
# 125    0.947053
# 126    0.718669
# 127    0.511379
# 128    0.898834
# 129    0.999443
# 130    0.998634
# 131    0.873956
# 132    0.983460
# 133    0.516524
# 134    0.804863
# 135    1.000000
# 136    0.682257
# 137    0.998244
# 138    0.694731
#
# [139 rows x 4 columns]

# %%
MLP_dmpv(A_index_c[4], B_index_c[4], C_index_c[4], D_index_c[4], E_index_c[4], F_index_c[4], x_size, p=4)
# Out:
# Train on 2807 samples, validate on 701 samples
# Epoch 1/50
# 2807/2807 [==============================] - 1s 437us/step - loss: 1.1262 - acc: 0.5369 - val_loss: 0.8334 - val_acc: 0.7204
# Epoch 2/50
# 2807/2807 [==============================] - 0s 62us/step - loss: 0.8000 - acc: 0.7118 - val_loss: 0.7000 - val_acc: 0.7561
# Epoch 3/50
# 2807/2807 [==============================] - 0s 60us/step - loss: 0.6573 - acc: 0.7688 - val_loss: 0.6571 - val_acc: 0.7675
# Epoch 4/50
# 2807/2807 [==============================] - 0s 51us/step - loss: 0.5779 - acc: 0.7884 - val_loss: 0.6186 - val_acc: 0.7832
# Epoch 5/50
# 2807/2807 [==============================] - 0s 48us/step - loss: 0.5132 - acc: 0.8144 - val_loss: 0.6592 - val_acc: 0.7675
# Epoch 6/50
# 2807/2807 [==============================] - 0s 47us/step - loss: 0.4597 - acc: 0.8315 - val_loss: 0.6264 - val_acc: 0.7903
# Epoch 7/50
# 2807/2807 [==============================] - 0s 49us/step - loss: 0.4215 - acc: 0.8465 - val_loss: 0.6589 - val_acc: 0.7775
# Epoch 8/50
# 2807/2807 [==============================] - 0s 51us/step - loss: 0.4021 - acc: 0.8550 - val_loss: 0.5991 - val_acc: 0.7974
# Epoch 9/50
# 2807/2807 [==============================] - 0s 64us/step - loss: 0.3430 - acc: 0.8860 - val_loss: 0.6157 - val_acc: 0.8046
# Epoch 10/50
# 2807/2807 [==============================] - 0s 53us/step - loss: 0.3088 - acc: 0.8942 - val_loss: 0.6414 - val_acc: 0.7989
# Epoch 11/50
# 2807/2807 [==============================] - 0s 62us/step - loss: 0.2745 - acc: 0.9067 - val_loss: 0.6463 - val_acc: 0.7960
# Epoch 12/50
# 2807/2807 [==============================] - 0s 39us/step - loss: 0.2620 - acc: 0.9116 - val_loss: 0.6785 - val_acc: 0.8003
# Epoch 35/50
# 2807/2807 [==============================] - 0s 49us/step - loss: 0.0304 - acc: 0.9904 - val_loss: 1.1975 - val_acc: 0.8088
# Epoch 36/50
# 2807/2807 [==============================] - 0s 60us/step - loss: 0.0333 - acc: 0.9893 - val_loss: 1.2532 - val_acc: 0.8046
# Epoch 37/50
# 2807/2807 [==============================] - 0s 60us/step - loss: 0.0247 - acc: 0.9929 - val_loss: 1.2926 - val_acc: 0.7974
# Epoch 38/50
# 2807/2807 [==============================] - 0s 38us/step - loss: 0.0242 - acc: 0.9914 - val_loss: 1.2617 - val_acc: 0.8088
# Epoch 39/50
# 2807/2807 [==============================] - 0s 37us/step - loss: 0.0304 - acc: 0.9886 - val_loss: 1.3385 - val_acc: 0.8003
# Epoch 40/50
# 2807/2807 [==============================] - 0s 37us/step - loss: 0.0237 - acc: 0.9925 - val_loss: 1.3132 - val_acc: 0.8060
# Epoch 41/50
# 2807/2807 [==============================] - 0s 38us/step - loss: 0.0306 - acc: 0.9907 - val_loss: 1.3417 - val_acc: 0.7960
# Epoch 42/50
# 2807/2807 [==============================] - 0s 37us/step - loss: 0.0184 - acc: 0.9947 - val_loss: 1.3612 - val_acc: 0.8017
# Epoch 43/50
# 2807/2807 [==============================] - 0s 37us/step - loss: 0.0180 - acc: 0.9939 - val_loss: 1.3601 - val_acc: 0.8046
# Epoch 44/50
# 2807/2807 [==============================] - 0s 37us/step - loss: 0.0289 - acc: 0.9918 - val_loss: 1.5412 - val_acc: 0.7960
# Epoch 45/50
# 2807/2807 [==============================] - 0s 41us/step - loss: 0.0168 - acc: 0.9957 - val_loss: 1.5316 - val_acc: 0.7917
# Epoch 46/50
# 2807/2807 [==============================] - 0s 38us/step - loss: 0.0210 - acc: 0.9939 - val_loss: 1.4638 - val_acc: 0.7974
# Epoch 47/50
# 2807/2807 [==============================] - 0s 37us/step - loss: 0.0150 - acc: 0.9957 - val_loss: 1.4093 - val_acc: 0.8046
# Epoch 48/50
# 2807/2807 [==============================] - 0s 39us/step - loss: 0.0274 - acc: 0.9932 - val_loss: 1.3796 - val_acc: 0.8046
# Epoch 49/50
# 2807/2807 [==============================] - 0s 38us/step - loss: 0.0227 - acc: 0.9922 - val_loss: 1.4154 - val_acc: 0.7989
# Epoch 50/50
# 2807/2807 [==============================] - 0s 40us/step - loss: 0.0178 - acc: 0.9943 - val_loss: 1.4379 - val_acc: 0.7989
# 701/701 [==============================] - 0s 488us/step
#
#
# 正解率= 0.798858773691338 loss= 1.4378568866793677
#               precision    recall  f1-score   support
#
#            0       0.69      0.81      0.75       174
#            1       0.87      0.87      0.87       180
#            2       0.83      0.77      0.80       167
#            3       0.83      0.74      0.78       179
#
#     accuracy                           0.80       700
#    macro avg       0.80      0.80      0.80       700
# weighted avg       0.80      0.80      0.80       700
#
# スポーツ : 0 / IT : 1 / 映画 : 2 / ライフ : 3
# 処理時間：8.584031820297241[s]
#                                                   text true_label pre_label  \
# 0                   J歴代6位の年俸から、“見事な右肩下がり”で落ちていった武田修宏       スポーツ        IT
# 1                           “岩崎恭子の再来”、天才美少女スイマーが本日登場！       スポーツ        IT
# 2                          「平成のマーメイド」は15歳、最年少の美少女スイマー       スポーツ        映画
# 3                           「格が違う」かわいい子だらけのなでしこ候補たち       スポーツ       ライフ
# 4      【Sports Watch】ゴール後のパフォーマンスで話題の日本代表・槙野、新ネタ明かす       スポーツ        映画
# 5                       【Sports Watch】ダルビッシュに第二子が誕生       スポーツ       ライフ
# 6                    【Sports Watch】人気女子ゴルファー、苦難の時代を語る       スポーツ       ライフ
# 7                【Sports Watch】元大関・千代大海、M-1王者にガン飛ばした       スポーツ       ライフ
# 8    【Sports Watch】内田篤人キッパリ！ 「よくないすか？ べつに。サッカー選手て...       スポーツ        IT
# 9      【Sports Watch】大人気ラウンドガールがCM出演、セクシーボディを披露!!       スポーツ        映画
# 10              【Sports Watch】最強ミランのサポート施設「ミランラボ」とは？       スポーツ       ライフ
# 11              【Sports Watch】東原亜希“デスブログ”、スポーツ界を超越       スポーツ       ライフ
# 12      【Sports Watch】海老蔵殴打事件、元祖夜遊びJリーガーも“絡まれることはある”       スポーツ        映画
# 13                     【Sports Watch】潮田玲子が“別人のようだ”!?       スポーツ       ライフ
# 14          【Sports Watch】進むフィギュアの高得点化、荒川のトリノ五輪時得点は——       スポーツ        映画
# 15                     まだまだある“キングカズ”の知られざるエピソード       スポーツ       ライフ
# 16                    エジプトのサッカー場暴動に「世界が日本を見習うべき」         スポーツ       ライフ
# 17                        オリックス公式アカウント「ヘディング脳」発言が波紋       スポーツ       ライフ
# 18          ダルビッシュ、紅白戦4失点も“問題なし”を強調。ファンから挑発的なツイートも!?       スポーツ       ライフ
# 19                          ハーフナー・マイク、番組のはからいに「変な汗出るわ」       スポーツ       ライフ
# 20                           ブラジルＷ杯時、最強の日本代表メンバーとは？       スポーツ       ライフ
# 21             ルーニーの「NFLよりペンキが乾くのを見てるほうがマシ」発言が波紋         スポーツ       ライフ
# 22                  五輪目指す山崎静代、芸能との両立には「両方をやってこそ意味がある」       スポーツ        IT
# 23                             元日本代表・久保の長女が「かわいい」と評判        スポーツ        映画
# 24               大麻密輸容疑でNOSAWA論外と紫雷イオが逮捕。イオ姉は絶縁状態を告白       スポーツ        映画
# 25                   小原と伊調、２人の金メダリストを生み出した青森県八戸市の魅力とは       スポーツ        IT
# 26                             崖っぷちから這い上がった復活のマーメイド       スポーツ        映画
# 27                                 底抜けに可愛い国内無敵のチャンピオン       スポーツ        IT
# 28                      本田モデルのスパイク登場も、「オモチャみたいだな」の声       スポーツ        IT
# 29                来月45歳のカズ 「サッカー選手は30歳までが常識かなと思ってた」       スポーツ        IT
# ..                                                 ...        ...       ...
# 111                                       ミソジニーの正体とは？        ライフ      スポーツ
# 112                             友達が多い人って、実は性格がよくない！？        ライフ      スポーツ
# 113                                夏につきもののアノ話…『私の恐怖体験』        ライフ        映画
# 114              夏バテよりも深刻な「新型秋バテ」は、1日2回の“紅茶”でリセット!?        ライフ        IT
# 115                                       天然はなぜモテルのか？        ライフ      スポーツ
# 116                                 夫より頼りになる存在「ママ友」とは？        ライフ      スポーツ
# 117                             奇跡の花が販売再開、青いバラの伝説とは？        ライフ      スポーツ
# 118                   女性のわがままを全て叶えた逸品「マイ フェラガモ」フェア開催        ライフ      スポーツ
# 119                           女性の通勤バッグは、なぜ大きくて重いのか？        ライフ      スポーツ
# 120               女性も驚愕!? スキンケアしていない人は70%と男性の意識の低さが判明        ライフ        IT
# 121                       好感度上昇中のサバサバ女子！ その複雑な胸の内とは？        ライフ      スポーツ
# 122                                      実録！ 彼が挨拶に来る日        ライフ        IT
# 123                          年間100日以上!? 無駄なダイエット生活を脱出        ライフ        映画
# 124                      意外！ 奥さん候補への近道は『オカン系女子』ってホント!?        ライフ        映画
# 125                    成就率は約20％！ 七夕に込めた願いごとは叶いやすいかも!?        ライフ      スポーツ
# 126                         日々の出来事を楽しく記録！ 思い出スクラップとは？        ライフ      スポーツ
# 127             普通の友だちとは何が違う!? 「堅い絆で結ばれた“堅とも”」とは!!        ライフ        映画
# 128                                     本当に信じられる占いとは？        ライフ      スポーツ
# 129                                 母親に夕食を作ってもらう独女はアリ？        ライフ      スポーツ
# 130                    海外セレブ注目のミラクルフード“亜麻の実”の美的効果とは？        ライフ      スポーツ
# 131                           独女の疑問……結婚後のマイホーム購入は当たり前？        ライフ        IT
# 132                                   男子が冷めてしまう女性とは!?        ライフ      スポーツ
# 133                                美しすぎる40代“美魔女”の正体とは        ライフ        映画
# 134  美人力アップの美容のためのプレゼントキャンペーン「0℃体験!?夏ひんやり洞窟ツアー夏...        ライフ        映画
# 135                           親から「まだ結婚しないの？」と言われなくなる時        ライフ      スポーツ
# 136                             言いにくい「芸能人の○○みたいにして」の一言        ライフ      スポーツ
# 137                貴方の気持ちを100文字に込めて〜デキルオンナのプレゼントとは？        ライフ      スポーツ
# 138                             通話料金が安くなるスマホアプリが登場！        ライフ      スポーツ
# 139        進化し続ける「レンジ専用食品」電子レンジを“相棒”にする「レンジェンヌ」とは!?        ライフ        IT
# 140                            顔のいい男を「かっこいい」と褒めるのは逆効果？        ライフ      スポーツ
#
#      prediction
# 0      0.994076
# 1      0.999944
# 2      0.967565
# 3      0.999962
# 4      0.999730
# 5      0.630491
# 6      0.588627
# 7      0.990847
# 8      0.999982
# 9      0.999569
# 10     0.834534
# 11     0.896254
# 12     1.000000
# 13     0.930777
# 14     0.594805
# 15     0.552707
# 16     0.749508
# 17     0.999987
# 18     0.982515
# 19     0.997117
# 20     0.947698
# 21     1.000000
# 22     0.999996
# 23     0.998613
# 24     1.000000
# 25     0.900728
# 26     0.558277
# 27     0.844751
# 28     0.863036
# 29     0.614785
# ..          ...
# 111    0.922801
# 112    0.941249
# 113    0.874824
# 114    0.995093
# 115    0.967286
# 116    0.999876
# 117    0.997967
# 118    0.999514
# 119    0.584473
# 120    0.973191
# 121    0.683633
# 122    0.626070
# 123    0.945154
# 124    0.999853
# 125    0.999997
# 126    0.775309
# 127    0.999904
# 128    0.834283
# 129    0.983943
# 130    0.978676
# 131    0.997454
# 132    0.973477
# 133    0.671206
# 134    0.924800
# 135    0.999641
# 136    0.449879
# 137    0.999653
# 138    0.999965
# 139    1.000000
# 140    0.906934
#
# [141 rows x 4 columns]

# %% [markdown]
# # dbow

# %%
def MLP_dbow(x_test, x_train, y_test, y_train, z_test, z_train, x_size, p):
    # MLPモデル構造を定義 --- (*5)
    MLP_model = Sequential()

    MLP_model.add(Dense(128, activation='relu', input_shape=(x_size,)))
    MLP_model.add(Dropout(0.2))
    MLP_model.add(Dense(128, activation='relu'))
    MLP_model.add(Dropout(0.2))
    MLP_model.add(Dense(128, activation='relu'))
    MLP_model.add(Dropout(0.2))
    MLP_model.add(Dense(nb_classes, activation='softmax'))

    # モデルをコンパイル --- (*6)
    MLP_model.compile(
        loss='categorical_crossentropy',
        optimizer=RMSprop(),
        metrics=['accuracy'])
    
    t1 = time.time()                 #　開始
    # 学習を実行 --- (*7)
    hist = MLP_model.fit(x_train, y_train,
              batch_size=128,
              epochs=50,
              verbose=1,
              validation_data=(x_test, y_test))
    t2 = time.time()                #　終了
    
   # モデルの保存
    MLP_model.save('./model/dbow_model_'+str(p)+'.hdf5')
    
    # モデルのロード
    model = load_model('./model/dbow_model_'+str(p)+'.hdf5')
    #  混同行列
    predict_classes = model.predict_classes(x_test[1:10000]) ### 予測したラベルを取得
    true_classes = np.argmax(y_test[1:10000], 1) ### 実際のラベルを取得

    # 評価する ---(*8)
    score = model.evaluate(x_test, y_test, verbose=1)
    print('\n')
    print("正解率=", score[1], 'loss=', score[0])

    #  適応率, 再現率, F値
    rep = metrics.classification_report(true_classes, predict_classes)
    print(rep)

    # 学習の様子をグラフへ描画 --- (*10)
    # Accuracy
    plt.figure(figsize=(20, 5)) # figureの縦横の大きさ
    plt.subplot(1,2,1)
    plt.plot(hist.history['acc'])
    plt.plot(hist.history['val_acc'])
    plt.title('Accuracy')
    plt.legend(['train', 'test'], loc='upper left')
    plt.grid()

    # Loss
    plt.subplot(1,2,2)
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('Loss')
    plt.legend(['train', 'test'], loc='upper left')
    plt.grid()

    MLP_print_cmx(true_classes, predict_classes)

    # 経過時間を表示
    elapsed_time = t2-t1
    print(f"処理時間：{elapsed_time}"+"[s]")

    LABELS = ["スポーツ", "IT", "映画", "ライフ"]
    A=[]
    B=[]
    C=[]
    D=[]
    for i, j, k in zip(x_test, y_test, z_test):
        pre = MLP_model.predict(np.array([i]))[0]
        n = pre.argmax()
        l=np.where(j==1.0)
        if LABELS[n]!=LABELS[l[0][0]]:
            A.append(LABELS[n])
            B.append(pre[n])
            C.append(LABELS[l[0][0]])
            D.append(k)

    df=pd.DataFrame({'text':D,
                                     'true_label':C, 
                                    'pre_label':A,
                                    'prediction':B}
                                   )

    #     df.to_excel('Excel/TF-IDF_MLP_'+str(p)+'.xlsx', encoding='UTF-16')
    display(df)

# %%
data_s=pickle.load(open('/Users/Baron/Document/text_mining/Data/pickle/Doc2Vec/Headline/d2v_headline_dbow.pickle', "rb"))
z_s = data_s[0]   # 内容
y_s = data_s[1]   # ラベル
x_s = data_s[2]   # 特徴量
kf = KFold(n_splits=5, shuffle=True, random_state=0)
nb_classes = 4
# ラベルデータをone-hotベクトルに直す --- (*3)
y_s = keras.utils.np_utils.to_categorical(y_s, nb_classes)

# データの次元数
x_size = x_s[0].shape[0]
y_size = y_s[0].shape[0]

A_index_s=[]
B_index_s=[]
C_index_s=[]
D_index_s=[]
E_index_s=[]
F_index_s=[]

# 交差検証
for train, test in kf.split(x_s):
    A_s=np.empty((0,x_size), int)
    B_s=np.empty((0,x_size), int)
    C_s=np.empty((0,y_size), int)
    D_s=np.empty((0,y_size), int)
    E_s = []
    F_s = []
    for i in test:
        A_s = np.append(A_s, [x_s[i]], axis=0)           # x_test
        C_s = np.append(C_s, [y_s[i]], axis=0)           # y_test
        E_s.append(z_s[i])                                     # z_test
    A_index_s.append(A_s)
    C_index_s.append(C_s)
    E_index_s.append(E_s)
    for j in train:
        B_s = np.append(B_s, [x_s[j]], axis=0)            # x_train
        D_s = np.append(D_s, [y_s[j]], axis=0)           # y_train
        F_s.append(z_s[j])                                      # z_train
    B_index_s.append(B_s)
    D_index_s.append(D_s)
    F_index_s.append(F_s)

# %%
MLP_dbow(A_index_s[0], B_index_s[0], C_index_s[0], D_index_s[0], E_index_s[0], F_index_s[0], x_size, p=0)

# %%
MLP_dbow(A_index_s[1], B_index_s[1], C_index_s[1], D_index_s[1], E_index_s[1], F_index_s[1], x_size, p=1)

# %%
MLP_dbow(A_index_s[2], B_index_s[2], C_index_s[2], D_index_s[2], E_index_s[2], F_index_s[2], x_size, p=2)

# %%
MLP_dbow(A_index_s[3], B_index_s[3], C_index_s[3], D_index_s[3], E_index_s[3], F_index_s[3], x_size, p=3)

# %%
MLP_dbow(A_index_s[4], B_index_s[4], C_index_s[4], D_index_s[4], E_index_s[4], F_index_s[4], x_size, p=4)

# %% [markdown]
# # グリッドサーチ

# %%
# # コピー2
# def MLP_grid(activation, optimizer, out_dim):
#     # MLPモデル構造を定義 --- (*5)
#     MLP_model = Sequential()
#     #  隠れ層     
#     MLP_model.add(Dense(out_dim, activation=activation, input_shape=(x_size,)))
#     MLP_model.add(Dropout(0.2))
#     MLP_model.add(Dense(out_dim, activation=activation))
#     MLP_model.add(Dropout(0.2))
#     #  出力層
#     MLP_model.add(Dense(nb_classes, activation='softmax'))

#     # モデルをコンパイル --- (*6)
#     MLP_model.compile(
#         loss='categorical_crossentropy',
#         optimizer=optimizer,
#         metrics=['accuracy'])
#     return MLP_model

# %%
# # データを返す関数
# def data(i):
#     # x_train, y_train, x_test, y_test
#     return B_index[i], D_index[i], A_index[i], C_index[i]

# %%
# activation = ["relu"]
# optimizer = ["rmsprop"]
# out_dim=[128]
# nb_epoch = [10, 20, 50]
# batch_size = [16, 64, 128]
# model = KerasClassifier(build_fn=MLP_gird, verbose=0)
# param_grid = dict(activation=activation, 
#                                 optimizer=optimizer, 
#                                 out_dim=out_dim, 
#                                 nb_epoch=nb_epoch, 
#                                 batch_size=batch_size)
# grid = GridSearchCV(estimator=model, param_grid=param_grid)

# %%
# # Data[0]:x_train, Data[1]:y_train, Data[2]:x_test, Data[3]:y_test
# grid_result = grid.fit(data(i=0)[0], data(i=0)[1])

# %%
# print (grid_result.best_score_)
# print (grid_result.best_params_)

# %%
# clf = grid_result.best_estimator_
# for t in range(5):
#     accuracy = clf.score(data(i=0)[i], data(i=0)[i])
#     print("\nAccuracy: %.2f" % (accuracy))
