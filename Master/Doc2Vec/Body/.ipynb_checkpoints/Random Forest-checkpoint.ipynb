# %%
import os
import pickle
import keras
import time

import numpy as np
import pandas as pd
import seaborn as sn
import random as rn
import tensorflow as tf
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
# Out:
# Using TensorFlow backend.

# %%
########################################
# ランダムフォレスト 
########################################
# データベースの読込 --- (*2)
data=pickle.load(open('/Users/Baron/Document/text_mining/Data/pickle/Doc2Vec/Body/d2v_body.pickle', "rb"))
z = data[0]
y = data[1]
x = data[2]
kf = KFold(n_splits=5, shuffle=True, random_state=0)

A_index = []
B_index = []
C_index = []
D_index = []
E_index = []
F_index = []

for train, test in kf.split(x):
    A = []
    B = []
    C = []
    D = []
    E = []
    F = []
    for i in test:
        A.append(x[i])       # x_test
        C.append(y[i])       # y_test
        E.append(z[i])       # z_test
    A_index.append(A)
    C_index.append(C)
    E_index.append(E)
    for j in train:
        B.append(x[j])       # x_train
        D.append(y[j])       # y_train
        F.append(z[j])       # z_train
    B_index.append(B)
    D_index.append(D)
    F_index.append(F)

# %%
########################################
#  混同行列 
########################################
def RF_print_cmx(y_true, y_pred):
    labels = sorted(list(set(y_true)))
    cmx_data = confusion_matrix(y_true, y_pred, labels=labels)
    df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)

    plt.figure(figsize = (12,8))
    sn.heatmap(df_cmx, annot=True, fmt="d") ### ヒートマップの表示仕様
    plt.title("Confusion Matrix")
    plt.xlabel("predict_classes")
    plt.ylabel("true_classes")
    plt.show()

    #     plt.savefig("c_matrix.png")
    #     plt.close()
    print('スポーツ : 0')
    print('IT           : 1')
    print('映画       : 2')
    print('ライフ     : 3')

# %%
def RF(x_test, x_train, y_test, y_train, z_test, z_train):
    RF_model = RandomForestClassifier()
    t1 = time.time()                 #　開始
    RF_model.fit(x_train, y_train)
    t2 = time.time()                #　終了
    predict = RF_model.predict(x_test)
    
    accuracy = metrics.accuracy_score(y_test, predict)
    cl_report = metrics.classification_report(y_test, predict)

    print('Train score: {}'.format(RF_model.score(x_train, y_train)))
    print("正解率 = ", accuracy)
    print("レポート\n", cl_report)
    
    RF_print_cmx(y_test, predict)
    
    # 経過時間を表示
    elapsed_time = t2-t1
    print(f"処理時間：{elapsed_time}"+"[s]")
    
    LABELS = ["スポーツ", "IT", "映画", "ライフ"]
    A=[]
    B=[]
    C=[]
    for i, j in zip(x_test, y_test):
        pre = RF_model.predict(np.array([i]))[0]
        A.append(LABELS[pre])
        C.append(LABELS[j])

    df=pd.DataFrame({'text':z_test,
                                     'true_label':C, 
                                    'pre_label':A})
#     # df.to_excel('Excel/TF-IDF_MLP.xlsx', encoding='UTF-16')
    display(df)

# %%
RF(A_index[0], B_index[0], C_index[0], D_index[0], E_index[0], F_index[0])
# Out:
# Train score: 1.0
# 正解率 =  0.9572649572649573
# レポート
#                precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       194
#            1       0.92      0.99      0.95       160
#            2       0.94      0.97      0.96       170
#            3       0.96      0.89      0.92       178
#
#     accuracy                           0.96       702
#    macro avg       0.96      0.96      0.96       702
# weighted avg       0.96      0.96      0.96       702
# スポーツ : 0
# IT           : 1
# 映画       : 2
# ライフ     : 3
# 処理時間：4.808241844177246[s]
#                                                   text true_label pre_label
# 0           【Sports Watch】フジテレビ・スポーツ番組の「韓日戦」表記の理由とは       スポーツ      スポーツ
# 1          【Sports Watch】不振続く松井秀に「マイナーでのプレーを余儀なくされる」       スポーツ      スポーツ
# 676                                イタくない「恋愛武勇伝」の語り方とは？        ライフ       ライフ
# 677                      話題の二股騒動……あなたはしたこと、されたことありますか？        ライフ       ライフ
# 678                                     元彼に執着する女は占い好き？        ライフ       ライフ
# 679             普通の友だちとは何が違う!? 「堅い絆で結ばれた“堅とも”」とは!!        ライフ       ライフ
# 680                  全然好きなタイプの男性じゃないのに、匂いで惹かれてしまうとき        ライフ       ライフ
# 681                   増え続ける最大級規模のアウトレットモール、独女が楽しむコツは？        ライフ       ライフ
# 682          「ドモホルンリンクル」の再春館製薬所が贈る、人の絆をつむぐムービーアプリ        ライフ        IT
# 683                     女性に支持される魅力的なメルセデス「新CLSクラス」を体感        ライフ        映画
# 684                           独女はレディコミ好き……!? その真相に迫る！        ライフ       ライフ
# 685  【オトナ女子コミック部】独女が読んでも爆笑必至!! キャラ立ち子育てマンガ『ママはテン...        ライフ       ライフ
# 686                            今の時代でも健在！「SNS嫌い」男性のいい分        ライフ       ライフ
# 687                             「結婚は？」「子どもは？」母の説教スルー術        ライフ       ライフ
# 688  くさったよめがあらわれた！vol.05「自分を変えたい…それは楽しめることをみつけること!...        ライフ       ライフ
# 689                                      今や自分磨きは社会貢献！？        ライフ       ライフ
# 690    【独女的コミックレビュー vol.1】 『花のズボラ飯』は女子的ひとりゴハンのお手本！        ライフ       ライフ
# 691                               本当はどうなの？ 年下くんとの恋の行方        ライフ       ライフ
# 692                    男性の家に上がったのに「その気がない」女性はアリかナシか？        ライフ       ライフ
# 693                      【独女的コミックレビュー】vol.5『おひとりさま物語』        ライフ       ライフ
# 694                                           独女的「幸福論」        ライフ       ライフ
# 695                                 独女の憧れ？「終の住処は老人ホーム」        ライフ       ライフ
# 696                 「3.11で変わったこと」をリアルに感じるアンケート結果を公開！        ライフ       ライフ
# 697               「独女×僕等がいた」恋愛術：男心に刺さる“待ち女”で勝ち組になるテク        ライフ       ライフ
# 698                             愛される？ 愛する？ 幸せなのはどっち!?        ライフ       ライフ
# 699                        「オス化診断」でホルモンバランスをセルフチェック！        ライフ       ライフ
# 700                     お金をかけずにおしゃれを楽しむxChange（古着交換会）        ライフ       ライフ
# 701                               バイキングという食文化をどう思う？        ライフ       ライフ
#
# [702 rows x 3 columns]

# %%
RF(A_index[1], B_index[1], C_index[1], D_index[1], E_index[1], F_index[1])
# Out:
# Train score: 1.0
# 正解率 =  0.9572649572649573
# レポート
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       180
#            1       0.95      0.97      0.96       193
#            2       0.95      0.96      0.96       169
#            3       0.95      0.89      0.92       160
#
#     accuracy                           0.96       702
#    macro avg       0.96      0.96      0.96       702
# weighted avg       0.96      0.96      0.96       702
# スポーツ : 0
# IT           : 1
# 映画       : 2
# ライフ     : 3
# 処理時間：4.960674047470093[s]
#                                                   text true_label pre_label
# 0                          日本、フランスとの対戦に「仮想スペインかよ」の声         スポーツ      スポーツ
# 1                          ノムさん、佐々木則夫監督に「50、60はハナタレ小僧」       スポーツ      スポーツ
# 2                【Sports Watch】泉浩と熱愛報道、末永遥「マスコミって恐ろしい」       スポーツ      スポーツ
# 676                                 独女のカラオケ……何歌っていますか？        ライフ       ライフ
# 677                                   カラオケで演歌を歌う女ゴコロ        ライフ       ライフ
# 678                  独女的映画レビュー vol.11 『食べて、祈って、恋をして』        ライフ       ライフ
# 679   意識過剰な私…不倫中のあなた…。行き着く先は女地獄？！独女的ブックレビュー『女地獄の歩き方』        ライフ       ライフ
# 680  どうやっても貯められない30代女子の貯金改革!! Vol.5「何事もバランスが大切！ ...        ライフ       ライフ
# 681                    独女も共感!? “イタい歌詞”で注目を浴びる奥 華子の世界        ライフ       ライフ
# 682                  女性のわがままを全て叶えた逸品 「マイ フェラガモ」フェア開催        ライフ        IT
# 683                            美容整形の志願者が次々と自己紹介をすることに        ライフ       ライフ
# 684                      まるで妊婦！？ モデルの7割が悩む「ポッコリお腹」        ライフ       ライフ
# 685                貴方の気持ちを100文字に込めて〜デキルオンナのプレゼントとは？        ライフ        IT
# 686                        「体の中からのスキンケア」をサポートするヨーグルト        ライフ       ライフ
# 687                                 次のバケーションはトルコに決まり！        ライフ        IT
# 688             「整形したい」女性が大半。コンプレックスを感じる顔のパーツはどこ？        ライフ       ライフ
# 689                      アウトドアやスポーツ時に便利な、携帯保存食作り講座開催        ライフ        IT
# 690  東京23区女ひとり風呂 vol.03「台東区・銭湯でアレ発見！」Presented by ...        ライフ       ライフ
# 691                        悲しいかな、おばさんファッションへと移行していく理由        ライフ       ライフ
# 692                               他人事ではない！ 占い依存症の独女たち        ライフ       ライフ
# 693                 【オトナ女子のリアルな悩み】付き合って10年。未だ結婚に進みません        ライフ       ライフ
# 694        【オトナ女子のリアルな悩み】仕事が決まらず、すべての運から見放されているようで        ライフ       ライフ
# 695                          大震災をきっかけに考える。在宅勤務はアリかナシか？        ライフ       ライフ
# 696                          懐かしさと勢いには要注意！？ 同窓会での恋愛事情        ライフ       ライフ
# 697                              給湯室で抹茶を楽しむ『給湯流茶道』とは？        ライフ       ライフ
# 698                           2011年こそ結婚したい！ 独女・独男の婚活事情        ライフ       ライフ
# 699                     イクメンプロジェクト!? それどころではありません。        ライフ       ライフ
# 700                         「お墓をよろしく」と言われたら、あなたはどうする？        ライフ       ライフ
# 701                                あの頃に戻りたい…。戻りたいのはいつ？        ライフ       ライフ
#
# [702 rows x 3 columns]

# %%
RF(A_index[2], B_index[2], C_index[2], D_index[1], E_index[2], F_index[2])
# Out:
# Train score: 1.0
# 正解率 =  0.9658119658119658
# レポート
#                precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       174
#            1       0.96      0.99      0.98       182
#            2       0.96      0.96      0.96       168
#            3       0.95      0.93      0.94       178
#
#     accuracy                           0.97       702
#    macro avg       0.97      0.97      0.97       702
# weighted avg       0.97      0.97      0.97       702
# スポーツ : 0
# IT           : 1
# 映画       : 2
# ライフ     : 3
# 処理時間：6.1053197383880615[s]
#                                                   text true_label pre_label
# 0       【Sports Watch】香川に続く日本人選手のドイツ・ブンデスリーガ移籍が決定       スポーツ      スポーツ
# 1         【Sports Watch／競馬】 心ない野次に騎手が激怒“「死ね」だけは許せない”       スポーツ      スポーツ
# 676    日本の大切な文化“お正月”について学び、情報発信をする「お正月キュレーター候補生」を大募集！        ライフ        IT
# 677                             女性のロングヘアーは何歳までOKなのか？        ライフ       ライフ
# 678                         真夏でもブーツやレギンスの独女——暑くないの？        ライフ       ライフ
# 679                                「変わらないね」のひと言に感じるコト        ライフ       ライフ
# 680  東京23区女ひとり風呂 vol.04「文京区・銭湯後はこの一杯！」Presented by ...        ライフ       ライフ
# 681                                 ジブリアニメの印象が変わるとき        ライフ       ライフ
# 682                                   オオカミはあなたを狙っている！         ライフ       ライフ
# 683                               浮気の証拠を握ったら、さてどうする！？        ライフ       ライフ
# 684                       「3秒」で恋愛対象外？ 残念なイケメン君が増殖中！？        ライフ       ライフ
# 685                                やってきました！「40代女子」上位時代        ライフ       ライフ
# 686                          極端な言動のアラフォーは『見放され女』予備軍に!?        ライフ       ライフ
# 687                               あなたは何犬？「犬診断」が巷で大人気        ライフ        IT
# 688  梅村ゆずの結婚どころじゃないんですっ！vol.2 Presented by ゆるっと...        ライフ       ライフ
# 689                                 会話が多い夫婦は何を話しているの？        ライフ       ライフ
# 690  くさったよめがあらわれた！vol.02「ムカつく上司がこんなにも好きになる!?」 pre...        ライフ       ライフ
# 691                                   本当はなりたい「すっぴん美人」        ライフ       ライフ
# 692                                韓国人の彼氏が徴兵されることについて        ライフ        映画
# 693                             復活愛はアリかナシか。独女たちの出会いと別れ        ライフ       ライフ
# 694            【独女的コミックレビュー】vol.6 『姉の結婚』に見る“枯れ気味女”の憂鬱        ライフ       ライフ
# 695    6月9日「ロックの日」10周年記念に“MIWA ROCK!!”に新モード「HARD」が追加        ライフ        映画
# 696                                 お金もあって家柄もいいは敬遠される？        ライフ       ライフ
# 697                               恋の駆け引きができる女、できない女        ライフ       ライフ
# 698                               学生時代の恋を忘れられないのはなぜか？        ライフ       ライフ
# 699                               今年の夏、女子はボーナスをどう使う？        ライフ        IT
# 700                                夏につきもののアノ話…『私の恐怖体験』        ライフ       ライフ
# 701                                       美人は損をしているのか？        ライフ       ライフ
#
# [702 rows x 3 columns]

# %%
RF(A_index[3], B_index[3], C_index[3], D_index[3], E_index[3], F_index[3])
# Out:
# Train score: 1.0
# 正解率 =  0.9700427960057061
# レポート
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       177
#            1       0.97      0.99      0.98       155
#            2       0.94      0.99      0.96       195
#            3       0.99      0.90      0.95       174
#
#     accuracy                           0.97       701
#    macro avg       0.97      0.97      0.97       701
# weighted avg       0.97      0.97      0.97       701
# スポーツ : 0
# IT           : 1
# 映画       : 2
# ライフ     : 3
# 処理時間：7.835813999176025[s]
#                                                   text true_label pre_label
# 0             【Sports Watch】松井秀が言いたい放題「もし対戦したら、笑っちゃう」       スポーツ      スポーツ
# 1    【Sports Watch】長谷川穂積、最愛の母が死去 “もし一つだけ願いが叶うなら・・・”       スポーツ      スポーツ
# 2                          中日・吉見の″インチキ!?″投手三冠に批判が相次ぐ       スポーツ      スポーツ
# 3                  ノムさんがボヤキおさめ。今年のプロ野球界を漢字一文字で表すと？       スポーツ      スポーツ
# 4    【Sports Watch】香川、アジア杯は「優勝した大会ではなくてケガをして終わった大会」       スポーツ      スポーツ
# 676  【オトナ女子映画部】宮崎あおい＆堺雅人「篤姫」コンビが体現する運命共同体の夫婦『ツレが...        ライフ       ライフ
# 677                               世界中で「カワイイ」日本が人気らしい        ライフ       ライフ
# 678                              「好きを仕事に！」2つの仕事をもつ女性たち        ライフ       ライフ
# 679                                  男の人の結婚指輪ってチェックする？        ライフ       ライフ
# 680                 オンナは“何番目の男”と結婚するのが一番幸せか？【オンナの本音編】        ライフ       ライフ
# 681                       独女的映画レビュー vol.8 『ブラック・スワン』        ライフ        映画
# 682                        ブロガーから大きな支持を得たスキンケアアイテムとは        ライフ       ライフ
# 683               ありのままの私を愛しなさい！ Presented by ゆるっとcafe        ライフ       ライフ
# 684  【オトナ女子コミック部】すべての女は“ブス”である。女の毒素が臭気を放つコミックエッ...        ライフ       ライフ
# 685                           大人女子がスカートの下に秘めるべきものとは？        ライフ       ライフ
# 686                           笑える？ 笑えない？ 独女の母のびっくり発言！        ライフ       ライフ
# 687                      年末年始にこそ語りたい、トイレットペーパー問題について        ライフ       ライフ
# 688     【オトナ女子映画部】なぜマリリン・モンローは“本命”になれないのか？『マリリン７日間の恋』        ライフ        映画
# 689                           おトクに断捨離できちゃう進化形の買取サービス        ライフ        IT
# 690               正直ちょっと面倒!?な 女子会の幹事をラクラクこなせる新サービスとは？        ライフ        IT
# 691                                    見た目で損をしていませんか？        ライフ       ライフ
# 692                     体温が高い女はモテる!? 温活女子でモテ体質にココア!?        ライフ       ライフ
# 693                                   2012年 独女たちの結婚観とは        ライフ       ライフ
# 694  どうやっても貯められない30代女子の貯金改革!! Vol.4「こだわりポイントでめさ...        ライフ       ライフ
# 695                                   バブル独女とロスジェネ独女        ライフ       ライフ
# 696                                恋と仕事のマンネリ打破テクニックとは？        ライフ       ライフ
# 697                     巷で話題の「アロハ診断」。あなたが輝くブランドは！？        ライフ       ライフ
# 698  くさったよめがあらわれた！vol.01「秋の夜長の妄想三昧」 presented by ゆ...        ライフ       ライフ
# 699                                 独女のTwitter、意外な楽しみ方        ライフ       ライフ
# 700                                       あなたは何様ですか？         ライフ       ライフ
#
# [701 rows x 3 columns]

# %%
RF(A_index[4], B_index[4], C_index[4], D_index[4], E_index[4], F_index[4])
# Out:
# Train score: 1.0
# 正解率 =  0.9657631954350927
# レポート
#                precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       175
#            1       0.97      0.96      0.96       179
#            2       0.96      0.97      0.97       168
#            3       0.95      0.94      0.95       179
#
#     accuracy                           0.97       701
#    macro avg       0.97      0.97      0.97       701
# weighted avg       0.97      0.97      0.97       701
# スポーツ : 0
# IT           : 1
# 映画       : 2
# ライフ     : 3
# 処理時間：7.08686375617981[s]
#                                                   text true_label pre_label
# 0        【Sports Watch】長谷部にスバリ直撃!! 「ぶっちゃけ今、彼女はいますか？」       スポーツ      スポーツ
# 1                           【Sports Watch】巨人1位の澤村、涙の理由       スポーツ      スポーツ
# 2                    サッカー米国女子代表が生出演も、訊くべき話は何一つ訊かず……       スポーツ      スポーツ
# 3                                  スザンヌ、斉藤との夜の夫婦生活に言及       スポーツ      スポーツ
# 4                         「ニッポンの夜明け」澤のバロンドール受賞に賞賛の声       スポーツ      スポーツ
# 679            スマートで美しい“サイフ美人”はロンドンっ娘！ その理由はカードにあり！        ライフ        IT
# 680                                 「優しい男」なのにモテない理由とは？        ライフ       ライフ
# 681                      日本人には良い油＝“フィッシュオイル”が足りていない！？        ライフ       ライフ
# 682                             友達が多い人って、実は性格がよくない！？        ライフ       ライフ
# 683                      『シーン別まつげメイク塾』でアナタの目ヂカラをUP！        ライフ       ライフ
# 684                    「愛はないけど嫌いじゃない」離婚に踏み切らない女たちの本音        ライフ       ライフ
# 685                              思いがけない出会いを引き寄せた行動とは？        ライフ       ライフ
# 686                      相次ぐ芸能人の“すっぴん”披露 その時、独女の心境は？        ライフ       ライフ
# 687                            恋愛感情がイマイチでも結婚はできるのか？        ライフ       ライフ
# 688                              女性が気になる ”女の香り“の正体を探る        ライフ       ライフ
# 689                                      冬の汗対策、どうしてる？        ライフ       ライフ
# 690  【オトナ女子コミック部】同居人はゲイの菜食主義者! アラサー独女向け癒しコメディ『にが...        ライフ       ライフ
# 691  どうやっても貯められない30代女子の貯金改革!! Vol.3「『パーキンソンの法則』が...        ライフ       ライフ
# 692                     このまま独女でいるなら家はどうする？ 独女たちの住宅事情        ライフ       ライフ
# 693     【オトナ女子コミック部】少女マンガの世界にどっぷりトリップ！『まんがファッション』        ライフ       ライフ
# 694      【オトナ女子映画部】綾瀬はるかよりも可愛い大杉漣に胸キュン！『映画 ひみつのアッコちゃん』        ライフ        映画
# 695               【オトナ女子映画部】恋に恋する15歳の少女が見せる強い母性『ヒミズ』        ライフ        映画
# 696  独女的映画レビュー vol.12 『ブリジット・ジョーンズの日記 きれそうなわたし...        ライフ       ライフ
# 697                                      自分にぴったりということ        ライフ       ライフ
# 698                                  資格って本当に転職に有利ですか？        ライフ       ライフ
# 699                                自分のことを名前で呼ぶ独女への提言        ライフ       ライフ
# 700                              現代版「独女がやるべき花嫁修業」とは？        ライフ       ライフ
#
# [701 rows x 3 columns]

# %%
pram_grid={
    "max_depth": [2,3, None],
    "n_estimators":[50,100,200,300,400,500],
#     "max_features": [1, 3, 10],
#     "min_samples_split": [2, 3, 10],
#     "min_samples_leaf": [1, 3, 10],
    "bootstrap": [True, False],
    "criterion": ["gini", "entropy"]
}

# %%
def RF_grid(x_test, x_train, y_test, y_train, z_test, z_train):
    classifier = grid_search.GridSearchCV(RandomForestClassifier(), 
                                                               pram_grid)
    
    classifier.fit(x_train, y_train)
    
    best = gscv.best_estimator_
    pred = best.predict(x_test)
    print(best)
    print(pred)

# %%
RF_grid(A_index[0], B_index[0], C_index[0], D_index[0], E_index[0], F_index[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-1f15684660cf> in <module>
# ----> 1 RF_grid(A_index[0], B_index[0], C_index[0], D_index[0], E_index[0], F_index[0])
#
# <ipython-input-2-cda796a16e87> in RF_grid(x_test, x_train, y_test, y_train, z_test, z_train)
#       1 def RF_grid(x_test, x_train, y_test, y_train, z_test, z_train):
# ----> 2     classifier = graid_search.GridSearchCV(RandomForestClassifier(),
#       3                                                                pram_grid)
#       4
#       5     classifier.fit(x_train, y_train)
#
# NameError: name 'graid_search' is not defined
