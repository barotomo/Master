# %%
import os
import pickle
import keras
import time

import numpy as np
import pandas as pd
import seaborn as sn
import random as rn
import tensorflow as tf
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.models import model_from_json
from keras.layers import Dense, Dropout
from keras.optimizers import RMSprop
from keras.optimizers import Adam
from tqdm import tqdm_notebook as tqdm
# Out:
# Using TensorFlow backend.

# %%
def MLP_print_cmx(y_true, y_pred):
    labels = sorted(list(set(y_true)))
    cmx_data = confusion_matrix(y_true, y_pred, labels=labels)

    df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)

    plt.figure(figsize = (12,8))
    sn.heatmap(df_cmx, annot=True, fmt="d") ### ヒートマップの表示仕様
    plt.title("Confusion Matrix")
    plt.xlabel("predict_classes")
    plt.ylabel("true_classes")
    plt.show()

# %%
########################################
# TF-IDF→MLP
########################################
data=pickle.load(open('/Users/Baron/Document/text_mining/Data/pickle/TF-IDF/Body/tfidf_body.pickle', "rb"))
z = data[0]
y = data[1]
x = data[2]
print(len(x[0]))
kf = KFold(n_splits=5, shuffle=True, random_state=0)
# 分類するラベルの数 --- (*1)
nb_classes = 4
# ラベルデータをone-hotベクトルに直す --- (*3)
y = keras.utils.np_utils.to_categorical(y, nb_classes)

# データの次元数
x_size = x[0].shape[0]
y_size = y[0].shape[0]

A_index=[]
B_index=[]
C_index=[]
D_index=[]
E_index=[]
F_index=[]

# 交差検証のための訓練用(80%)とテスト用(20%)を作成
for train, test in kf.split(x):
    A=np.empty((0,x_size), int)
    B=np.empty((0,x_size), int)
    C=np.empty((0,y_size), int)
    D=np.empty((0,y_size), int)
    E = []
    F = []
    for i in test:
        A = np.append(A, [x[i]], axis=0)           # x_test
        C = np.append(C, [y[i]], axis=0)           # y_test
        E.append(z[i])                                          # z_test
    A_index.append(A)
    C_index.append(C)
    E_index.append(E)
    for j in train:
        B = np.append(B, [x[j]], axis=0)            # x_train
        D = np.append(D, [y[j]], axis=0)           # y_train
        F.append(z[j])                                         # z_train
    B_index.append(B)
    D_index.append(D)
    F_index.append(F)
# Out:
# 52659
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-1f7ca21d5fb7> in <module>
#      40     E_index.append(E)
#      41     for j in train:
# ---> 42         B = np.append(B, [x[j]], axis=0)            # x_train
#      43         D = np.append(D, [y[j]], axis=0)           # y_train
#      44         F.append(z[j])                                         # z_train
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in append(arr, values, axis)
#    4692         values = ravel(values)
#    4693         axis = arr.ndim-1
# -> 4694     return concatenate((arr, values), axis=axis)
#    4695
#    4696
#
# KeyboardInterrupt:

# %%
def MLP(x_test, x_train, y_test, y_train, z_test, z_train, x_size, p):
    # MLPモデル構造を定義 --- (*5)
    MLP_model = Sequential()
    MLP_model.add(Dense(512, activation='relu', input_shape=(x_size,)))
    MLP_model.add(Dropout(0.2))
    MLP_model.add(Dense(512, activation='relu'))
    MLP_model.add(Dropout(0.2))
    MLP_model.add(Dense(nb_classes, activation='softmax'))

    # モデルをコンパイル --- (*6)
    MLP_model.compile(
        loss='categorical_crossentropy',
        optimizer=RMSprop(),
        metrics=['accuracy'])
    
    t1 = time.time()                 #　開始
    # 学習を実行 --- (*7)
    hist = MLP_model.fit(x_train, y_train,
              batch_size=128, 
              epochs=20,
              verbose=1,
              validation_data=(x_test, y_test))
    t2 = time.time()                #　終了
    
    #  混同行列
    predict_classes = MLP_model.predict_classes(x_test[1:10000]) ### 予測したラベルを取得
    true_classes = np.argmax(y_test[1:10000], 1) ### 実際のラベルを取得
    
    # 評価する ---(*8)
    score = MLP_model.evaluate(x_test, y_test, verbose=1)
    print('\n')
    print("正解率=", score[1], 'loss=', score[0])
    
    #  適応率, 再現率, F値
    rep = metrics.classification_report(true_classes, predict_classes)
    print(rep)

    # 重みデータを保存 --- (*9)
    MLP_model.save_weights('./model/TFIDF_body_model_'+str(p)+'.hdf5')

    # 学習の様子をグラフへ描画 --- (*10)
    # Accuracy
    plt.figure(figsize=(20, 5)) # figureの縦横の大きさ
    plt.subplot(1,2,1)
    plt.plot(hist.history['acc'])
    plt.plot(hist.history['val_acc'])
    plt.title('Accuracy')
    plt.legend(['train', 'test'], loc='upper left')
    plt.grid()

    # Loss
    plt.subplot(1,2,2)
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('Loss')
    plt.legend(['train', 'test'], loc='upper left')
    plt.grid()
    
    MLP_print_cmx(true_classes, predict_classes)
    
    # 経過時間を表示
    elapsed_time = t2-t1
    print(f"処理時間：{elapsed_time}"+"[s]")
    
    LABELS = ["スポーツ", "IT", "映画", "ライフ"]
    A=[]
    B=[]
    C=[]
    D=[]
    for i, j, k in zip(x_test, y_test, z_test):
        pre = MLP_model.predict(np.array([i]))[0]
        n = pre.argmax()
        l=np.where(j==1.0)
        if LABELS[n]!=LABELS[l[0][0]]:
            A.append(LABELS[n])
            B.append(pre[n])
            C.append(LABELS[l[0][0]])
            D.append(k)

    df=pd.DataFrame({'text':D,
                                     'true_label':C, 
                                    'pre_label':A,
                                    'prediction':B}
                                   )
    
#     df.to_excel('Excel/TF-IDF_MLP_'+str(p)+'.xlsx', encoding='UTF-16')
    display(df)

# %%
MLP(A_index[0], B_index[0], C_index[0], D_index[0], E_index[0], F_index[0], x_size, p=0)
# Out:
# Train on 2806 samples, validate on 702 samples
# Epoch 1/20
# 2806/2806 [==============================] - 17s 6ms/step - loss: 0.5965 - acc: 0.8706 - val_loss: 0.1235 - val_acc: 0.9701
# Epoch 2/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 0.0308 - acc: 0.9961 - val_loss: 0.0798 - val_acc: 0.9801
# Epoch 3/20
# 2806/2806 [==============================] - 12s 4ms/step - loss: 0.0043 - acc: 1.0000 - val_loss: 0.0707 - val_acc: 0.9772
# Epoch 4/20
# 2806/2806 [==============================] - 12s 4ms/step - loss: 8.3001e-04 - acc: 1.0000 - val_loss: 0.0699 - val_acc: 0.9786
# Epoch 5/20
# 2806/2806 [==============================] - 12s 4ms/step - loss: 2.1724e-04 - acc: 1.0000 - val_loss: 0.0730 - val_acc: 0.9772
# Epoch 6/20
# 2806/2806 [==============================] - 12s 4ms/step - loss: 6.4558e-05 - acc: 1.0000 - val_loss: 0.0764 - val_acc: 0.9786
# Epoch 7/20
# 2806/2806 [==============================] - 11s 4ms/step - loss: 1.9553e-05 - acc: 1.0000 - val_loss: 0.0798 - val_acc: 0.9772
# Epoch 8/20
# 2806/2806 [==============================] - 11s 4ms/step - loss: 6.8507e-06 - acc: 1.0000 - val_loss: 0.0830 - val_acc: 0.9772
# Epoch 9/20
# 2806/2806 [==============================] - 12s 4ms/step - loss: 2.7043e-06 - acc: 1.0000 - val_loss: 0.0869 - val_acc: 0.9772
# Epoch 10/20
# 2806/2806 [==============================] - 12s 4ms/step - loss: 1.3765e-06 - acc: 1.0000 - val_loss: 0.0881 - val_acc: 0.9786
# Epoch 11/20
# 2806/2806 [==============================] - 12s 4ms/step - loss: 6.6976e-07 - acc: 1.0000 - val_loss: 0.0859 - val_acc: 0.9772
# Epoch 12/20
# 2806/2806 [==============================] - 12s 4ms/step - loss: 4.1672e-07 - acc: 1.0000 - val_loss: 0.0868 - val_acc: 0.9786
# Epoch 13/20
# 2806/2806 [==============================] - 12s 4ms/step - loss: 3.0620e-07 - acc: 1.0000 - val_loss: 0.0897 - val_acc: 0.9772
# Epoch 14/20
# 2806/2806 [==============================] - 12s 4ms/step - loss: 2.4256e-07 - acc: 1.0000 - val_loss: 0.0898 - val_acc: 0.9786
# Epoch 15/20
# 2806/2806 [==============================] - 12s 4ms/step - loss: 1.8493e-07 - acc: 1.0000 - val_loss: 0.0902 - val_acc: 0.9772
# Epoch 16/20
# 2806/2806 [==============================] - 12s 4ms/step - loss: 1.9239e-07 - acc: 1.0000 - val_loss: 0.0958 - val_acc: 0.9786
# Epoch 17/20
# 2806/2806 [==============================] - 12s 4ms/step - loss: 1.7915e-07 - acc: 1.0000 - val_loss: 0.0927 - val_acc: 0.9786
# Epoch 18/20
# 2806/2806 [==============================] - 12s 4ms/step - loss: 1.6732e-07 - acc: 1.0000 - val_loss: 0.0934 - val_acc: 0.9801
# Epoch 19/20
# 2806/2806 [==============================] - 12s 4ms/step - loss: 1.6159e-07 - acc: 1.0000 - val_loss: 0.0921 - val_acc: 0.9801
# Epoch 20/20
# 2806/2806 [==============================] - 12s 4ms/step - loss: 1.6218e-07 - acc: 1.0000 - val_loss: 0.0906 - val_acc: 0.9772
# 702/702 [==============================] - 1s 1ms/step
#
#
# 正解率= 0.9772079772079773 loss= 0.09056428833028828
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       193
#            1       0.99      0.98      0.99       160
#            2       0.96      0.98      0.97       170
#            3       0.97      0.96      0.97       178
#
#     accuracy                           0.98       701
#    macro avg       0.98      0.98      0.98       701
# weighted avg       0.98      0.98      0.98       701
# 処理時間：249.72856402397156[s]
#                                                  text true_label pre_label  \
# 0        【Sports Watch】宮崎大輔に、妻は“朝まで遊んで。スポーツ選手ですよ”       スポーツ       ライフ
# 1              【Sports Watch／競馬】 あの名物珍名馬主・今年は役職シリーズ？       スポーツ       ライフ
# 2          【Sports Watch／競馬】 迷走中!? 『うまプロ！』は何がしたいのか—       スポーツ        映画
# 3         御苦労さま！そしてありがとう！ スペースシャトル・ディスカバリー号、最後の飛行         IT        映画
# 4         本日のGoogleロゴはやり投 Googleロゴがスポーツ関連画像に変化第七弾         IT      スポーツ
# 5    本日のGoogleロゴはテーブルテニス Googleロゴがスポーツ関連画像に変化第四弾         IT      スポーツ
# 6                             “夢を追う”子供と“夢を諦めさせる”親の気持ち         映画       ライフ
# 7                  【DVDエンター！】“5マタ”の吉高由里子が最後に選んだ結婚相手         映画       ライフ
# 8            【GOGW映画 友人編】崖っぷち女が、親友の座を掛けて完璧美女と友情バトル         映画       ライフ
# 9   Windows＆LinuxのデュアルOS！ Thinkpad X1 Hybrid 3:9よ...        ライフ        IT
# 10  【オトナ女子映画部】この世で一番恐い女は？ 映画を超えたリアルサスペンス『ヘルタースケルター』        ライフ        映画
# 11      【オトナ女子映画部】綾瀬はるかよりも可愛い大杉漣に胸キュン！『映画 ひみつのアッコちゃん』        ライフ        映画
# 12            オトナ女子たちの圧倒的支持をうけ、ドラマ10『はつ恋』の一挙再放送が決定！        ライフ        映画
# 13                             ロンドン五輪、独女が注目している選手は？        ライフ      スポーツ
# 14  同世代女性の心をガッチリ掴んだ「セックス・アンド・ザ・シティ2 ［ザ・ムービー］...        ライフ        映画
# 15                           日本←→韓国ドラマのリメイク作品、どう思う？        ライフ        映画
#
#     prediction
# 0     0.938563
# 1     0.455494
# 2     0.574856
# 3     0.520840
# 4     0.558656
# 5     0.999363
# 6     0.828017
# 7     0.626026
# 8     0.828545
# 9     1.000000
# 10    0.999454
# 11    0.812473
# 12    0.947722
# 13    0.997497
# 14    0.989940
# 15    0.650720

# %%
MLP(A_index[1], B_index[1], C_index[1], D_index[1], E_index[1], F_index[1], x_size, p=1)
# Out:
# Train on 2806 samples, validate on 702 samples
# Epoch 1/20
# 2806/2806 [==============================] - 17s 6ms/step - loss: 0.6115 - acc: 0.8692 - val_loss: 0.0810 - val_acc: 0.9886
# Epoch 2/20
# 2806/2806 [==============================] - 14s 5ms/step - loss: 0.0352 - acc: 0.9947 - val_loss: 0.0332 - val_acc: 0.9929
# Epoch 3/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 0.0059 - acc: 0.9993 - val_loss: 0.0219 - val_acc: 0.9943
# Epoch 4/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0173 - val_acc: 0.9943
# Epoch 5/20
# 2806/2806 [==============================] - 13s 4ms/step - loss: 2.5744e-04 - acc: 1.0000 - val_loss: 0.0146 - val_acc: 0.9957
# Epoch 6/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 7.6502e-05 - acc: 1.0000 - val_loss: 0.0127 - val_acc: 0.9957
# Epoch 7/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 2.2806e-05 - acc: 1.0000 - val_loss: 0.0121 - val_acc: 0.9957
# Epoch 8/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 8.5205e-06 - acc: 1.0000 - val_loss: 0.0120 - val_acc: 0.9957
# Epoch 9/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 3.1350e-06 - acc: 1.0000 - val_loss: 0.0119 - val_acc: 0.9972
# Epoch 10/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 1.5789e-06 - acc: 1.0000 - val_loss: 0.0115 - val_acc: 0.9957
# Epoch 11/20
# 2806/2806 [==============================] - 12s 4ms/step - loss: 7.8625e-07 - acc: 1.0000 - val_loss: 0.0114 - val_acc: 0.9957
# Epoch 12/20
# 2806/2806 [==============================] - 12s 4ms/step - loss: 4.6996e-07 - acc: 1.0000 - val_loss: 0.0113 - val_acc: 0.9957
# Epoch 13/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 3.5444e-07 - acc: 1.0000 - val_loss: 0.0114 - val_acc: 0.9957
# Epoch 14/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 2.5843e-07 - acc: 1.0000 - val_loss: 0.0116 - val_acc: 0.9957
# Epoch 15/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 2.2990e-07 - acc: 1.0000 - val_loss: 0.0112 - val_acc: 0.9957
# Epoch 16/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 1.9664e-07 - acc: 1.0000 - val_loss: 0.0111 - val_acc: 0.9957
# Epoch 17/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 1.7905e-07 - acc: 1.0000 - val_loss: 0.0118 - val_acc: 0.9957
# Epoch 18/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 1.7365e-07 - acc: 1.0000 - val_loss: 0.0117 - val_acc: 0.9957
# Epoch 19/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 1.7505e-07 - acc: 1.0000 - val_loss: 0.0116 - val_acc: 0.9972
# Epoch 20/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 1.6310e-07 - acc: 1.0000 - val_loss: 0.0117 - val_acc: 0.9957
# 702/702 [==============================] - 1s 1ms/step
#
#
# 正解率= 0.9957264957264957 loss= 0.011659255805613774
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       179
#            1       0.99      0.99      0.99       193
#            2       0.99      1.00      1.00       169
#            3       0.99      0.99      0.99       160
#
#     accuracy                           1.00       701
#    macro avg       1.00      1.00      1.00       701
# weighted avg       1.00      1.00      1.00       701
# 処理時間：261.94863510131836[s]
#                                    text true_label pre_label  prediction
# 0  夏と言えば朝顔！ 小学生時代を思い起こさせるアサガオ観察日記ツイート         IT       ライフ    0.990076
# 1   【オトナ女子映画部】林由美香、本能のままに生きた1人の女優『監督失格』        ライフ        映画    0.549823
# 2                      意外と身近にあるレアアースを知る        ライフ        IT    0.559119

# %%
MLP(A_index[2], B_index[2], C_index[2], D_index[2], E_index[2], F_index[2], x_size, p=2)
# Out:
# Train on 2806 samples, validate on 702 samples
# Epoch 1/20
# 2806/2806 [==============================] - 17s 6ms/step - loss: 0.5767 - acc: 0.8885 - val_loss: 0.1202 - val_acc: 0.9701
# Epoch 2/20
# 2806/2806 [==============================] - 14s 5ms/step - loss: 0.0310 - acc: 0.9964 - val_loss: 0.0784 - val_acc: 0.9801
# Epoch 3/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 0.0061 - acc: 0.9993 - val_loss: 0.0631 - val_acc: 0.9815
# Epoch 4/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 0.0019 - acc: 0.9996 - val_loss: 0.0617 - val_acc: 0.9786
# Epoch 5/20
# 2806/2806 [==============================] - 13s 4ms/step - loss: 2.9256e-04 - acc: 1.0000 - val_loss: 0.0614 - val_acc: 0.9801
# Epoch 6/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 9.4602e-05 - acc: 1.0000 - val_loss: 0.0638 - val_acc: 0.9815
# Epoch 7/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 2.4539e-05 - acc: 1.0000 - val_loss: 0.0664 - val_acc: 0.9786
# Epoch 8/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 8.3159e-06 - acc: 1.0000 - val_loss: 0.0677 - val_acc: 0.9801
# Epoch 9/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 3.4108e-06 - acc: 1.0000 - val_loss: 0.0706 - val_acc: 0.9815
# Epoch 10/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 1.7714e-06 - acc: 1.0000 - val_loss: 0.0740 - val_acc: 0.9815
# Epoch 11/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 8.3390e-07 - acc: 1.0000 - val_loss: 0.0762 - val_acc: 0.9815
# Epoch 12/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 4.6042e-07 - acc: 1.0000 - val_loss: 0.0790 - val_acc: 0.9786
# Epoch 13/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 3.3373e-07 - acc: 1.0000 - val_loss: 0.0788 - val_acc: 0.9801
# Epoch 14/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 2.6181e-07 - acc: 1.0000 - val_loss: 0.0801 - val_acc: 0.9801
# Epoch 15/20
# 2806/2806 [==============================] - 12s 4ms/step - loss: 2.2642e-07 - acc: 1.0000 - val_loss: 0.0812 - val_acc: 0.9801
# Epoch 16/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 1.8859e-07 - acc: 1.0000 - val_loss: 0.0815 - val_acc: 0.9815
# Epoch 17/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 1.9281e-07 - acc: 1.0000 - val_loss: 0.0828 - val_acc: 0.9801
# Epoch 18/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 1.7270e-07 - acc: 1.0000 - val_loss: 0.0860 - val_acc: 0.9815
# Epoch 19/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 1.7344e-07 - acc: 1.0000 - val_loss: 0.0841 - val_acc: 0.9801
# Epoch 20/20
# 2806/2806 [==============================] - 13s 5ms/step - loss: 1.5534e-07 - acc: 1.0000 - val_loss: 0.0851 - val_acc: 0.9801
# 702/702 [==============================] - 1s 1ms/step
#
#
# 正解率= 0.9800569802267939 loss= 0.08514897270888314
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       173
#            1       0.97      0.98      0.97       182
#            2       0.98      0.99      0.98       168
#            3       0.98      0.96      0.97       178
#
#     accuracy                           0.98       701
#    macro avg       0.98      0.98      0.98       701
# weighted avg       0.98      0.98      0.98       701
# 処理時間：266.107262134552[s]
#                                                  text true_label pre_label  \
# 0   【Sports Watch／競馬】 配当上乗せの「JRAプレミアムレース」ではこの馬券を買え！       スポーツ        IT
# 1          カワイイは正義！ おかもとまりさんのカワイすぎる顔真似メイキングが反則過ぎる         IT       ライフ
# 2             価格が安価で矯正を気づかれない！綺麗な歯並びになれる、歯列矯正の最前線         IT       ライフ
# 3                愛される英王子 裸で敬礼！ ハリー英国王子に対する英国軍人の大いなる愛         IT        映画
# 4                 細かな違いや使用感がわかる！ありそうでなかった白髪染め体験記サイト         IT       ライフ
# 5        アメイジング・スパイダーマンが「LINE」とコラボ、期間限定スタンプも登場         映画        IT
# 6               魅力満載なスマホ向け放送局「NOTTV（ノッティーヴィー）」はじまる！         映画        IT
# 7             「大切なあなたに見せたい景色」をテーマに、Web上でフォトコンテスト開催中！        ライフ        IT
# 8       【Krush】8・12梶原龍児＆寺戸伸近の王者コンビがメインに登場！全カードの試合順        ライフ      スポーツ
# 9                           ガラケー感覚で使える次世代スマホを要チェック！        ライフ        IT
# 10                     女性に支持される魅力的なメルセデス「新CLSクラス」を体感        ライフ        映画
# 11          映画を観ながらダイエット！「映画ヨガ」をカンタンに学べる無料動画が公開中        ライフ        映画
# 12                   若い男子たちが激しく振り回される、あのハイテンションCMって？        ライフ        映画
# 13                音楽とスポーツをファッショナブルに楽しむためのヘッドホンが誕生        ライフ        IT
#
#     prediction
# 0     0.619232
# 1     0.997215
# 2     0.924573
# 3     0.865349
# 4     0.949265
# 5     0.509989
# 6     0.999574
# 7     0.986914
# 8     0.994875
# 9     0.949697
# 10    0.810039
# 11    0.994076
# 12    0.627320
# 13    0.804569

# %%
MLP(A_index[3], B_index[3], C_index[3], D_index[3], E_index[3], F_index[3], x_size, p=3)
# Out:
# Train on 2807 samples, validate on 701 samples
# Epoch 1/20
# 2807/2807 [==============================] - 17s 6ms/step - loss: 0.5834 - acc: 0.8824 - val_loss: 0.0997 - val_acc: 0.9829
# Epoch 2/20
# 2807/2807 [==============================] - 14s 5ms/step - loss: 0.0324 - acc: 0.9957 - val_loss: 0.0454 - val_acc: 0.9900
# Epoch 3/20
# 2807/2807 [==============================] - 14s 5ms/step - loss: 0.0056 - acc: 0.9996 - val_loss: 0.0347 - val_acc: 0.9886
# Epoch 4/20
# 2807/2807 [==============================] - 16s 6ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 0.0336 - val_acc: 0.9843
# Epoch 5/20
# 2807/2807 [==============================] - 15s 5ms/step - loss: 2.6892e-04 - acc: 1.0000 - val_loss: 0.0318 - val_acc: 0.9857
# Epoch 6/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 7.5610e-05 - acc: 1.0000 - val_loss: 0.0321 - val_acc: 0.9886
# Epoch 7/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 2.5864e-05 - acc: 1.0000 - val_loss: 0.0313 - val_acc: 0.9886
# Epoch 8/20
# 2807/2807 [==============================] - 14s 5ms/step - loss: 8.3180e-06 - acc: 1.0000 - val_loss: 0.0336 - val_acc: 0.9886
# Epoch 9/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 3.5941e-06 - acc: 1.0000 - val_loss: 0.0334 - val_acc: 0.9886
# Epoch 10/20
# 2807/2807 [==============================] - 14s 5ms/step - loss: 1.5948e-06 - acc: 1.0000 - val_loss: 0.0327 - val_acc: 0.9886
# Epoch 11/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 7.2698e-07 - acc: 1.0000 - val_loss: 0.0365 - val_acc: 0.9886
# Epoch 12/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 4.7968e-07 - acc: 1.0000 - val_loss: 0.0387 - val_acc: 0.9886
# Epoch 13/20
# 2807/2807 [==============================] - 14s 5ms/step - loss: 3.3731e-07 - acc: 1.0000 - val_loss: 0.0370 - val_acc: 0.9886
# Epoch 14/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 2.5519e-07 - acc: 1.0000 - val_loss: 0.0352 - val_acc: 0.9886
# Epoch 15/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 2.2113e-07 - acc: 1.0000 - val_loss: 0.0383 - val_acc: 0.9886
# Epoch 16/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 1.9752e-07 - acc: 1.0000 - val_loss: 0.0375 - val_acc: 0.9886
# Epoch 17/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 1.8056e-07 - acc: 1.0000 - val_loss: 0.0381 - val_acc: 0.9886
# Epoch 18/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 1.8506e-07 - acc: 1.0000 - val_loss: 0.0396 - val_acc: 0.9886
# Epoch 19/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 1.6208e-07 - acc: 1.0000 - val_loss: 0.0404 - val_acc: 0.9900
# Epoch 20/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 1.5783e-07 - acc: 1.0000 - val_loss: 0.0382 - val_acc: 0.9886
# 701/701 [==============================] - 1s 1ms/step
#
#
# 正解率= 0.9885877318116976 loss= 0.038210875813694575
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       176
#            1       0.99      0.99      0.99       155
#            2       0.97      1.00      0.99       195
#            3       0.99      0.97      0.98       174
#
#     accuracy                           0.99       700
#    macro avg       0.99      0.99      0.99       700
# weighted avg       0.99      0.99      0.99       700
# 処理時間：276.6980559825897[s]
#                                                 text true_label pre_label  \
# 0   117万2132件の動画中最高の1本！ニコニコ動画「第4回動画アワード」グランプリ作品決定         IT        映画
# 1                   夏のボーナス金額は増！ ただし商品の購入に充てる割合は大幅減         IT       ライフ
# 2    6月9日「ロックの日」10周年記念に“MIWA ROCK!!”に新モード「HARD」が追加        ライフ        IT
# 3          「ドモホルンリンクル」の再春館製薬所が贈る、人の絆をつむぐムービーアプリ        ライフ        IT
# 4  【オトナ女子映画部】なぜアメリカ人はヴァンパイアを好むのか 『トワイライト・サーガ／...        ライフ        映画
# 5  【オトナ女子映画部】アラサーアイドルがヒーローに！安っぽさやくだらなさを楽しむ『エイ...        ライフ        映画
# 6  【オトナ女子映画部】新ヒロインの小悪魔ぶりは学ぶべきポイントだらけ！ 『アメイジ...        ライフ        映画
# 7             島田秀平が木下優樹菜に“安産”＆“夫婦円満”のパワースポットをご紹介        ライフ        映画
#
#    prediction
# 0    0.533725
# 1    0.999593
# 2    0.618001
# 3    0.968582
# 4    0.681684
# 5    0.981778
# 6    0.994772
# 7    0.783239

# %%
MLP(A_index[4], B_index[4], C_index[4], D_index[4], E_index[4], F_index[4], x_size, p=4)
# Out:
# Train on 2807 samples, validate on 701 samples
# Epoch 1/20
# 2807/2807 [==============================] - 17s 6ms/step - loss: 0.6106 - acc: 0.8457 - val_loss: 0.1126 - val_acc: 0.9772
# Epoch 2/20
# 2807/2807 [==============================] - 14s 5ms/step - loss: 0.0330 - acc: 0.9957 - val_loss: 0.0581 - val_acc: 0.9843
# Epoch 3/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 0.0057 - acc: 0.9996 - val_loss: 0.0520 - val_acc: 0.9815
# Epoch 4/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 0.0418 - val_acc: 0.9886
# Epoch 5/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 2.7769e-04 - acc: 1.0000 - val_loss: 0.0403 - val_acc: 0.9886
# Epoch 6/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 8.2245e-05 - acc: 1.0000 - val_loss: 0.0383 - val_acc: 0.9900
# Epoch 7/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 2.1577e-05 - acc: 1.0000 - val_loss: 0.0389 - val_acc: 0.9900
# Epoch 8/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 7.9216e-06 - acc: 1.0000 - val_loss: 0.0397 - val_acc: 0.9900
# Epoch 9/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 3.2319e-06 - acc: 1.0000 - val_loss: 0.0398 - val_acc: 0.9900
# Epoch 10/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 1.4325e-06 - acc: 1.0000 - val_loss: 0.0404 - val_acc: 0.9900
# Epoch 11/20
# 2807/2807 [==============================] - 14s 5ms/step - loss: 7.3377e-07 - acc: 1.0000 - val_loss: 0.0419 - val_acc: 0.9900
# Epoch 12/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 4.2692e-07 - acc: 1.0000 - val_loss: 0.0426 - val_acc: 0.9900
# Epoch 13/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 2.9832e-07 - acc: 1.0000 - val_loss: 0.0423 - val_acc: 0.9900
# Epoch 14/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 2.7025e-07 - acc: 1.0000 - val_loss: 0.0431 - val_acc: 0.9900
# Epoch 15/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 2.2871e-07 - acc: 1.0000 - val_loss: 0.0447 - val_acc: 0.9900
# Epoch 16/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 1.9578e-07 - acc: 1.0000 - val_loss: 0.0436 - val_acc: 0.9900
# Epoch 17/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 1.7784e-07 - acc: 1.0000 - val_loss: 0.0438 - val_acc: 0.9900
# Epoch 18/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 1.6767e-07 - acc: 1.0000 - val_loss: 0.0449 - val_acc: 0.9900
# Epoch 19/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 1.6168e-07 - acc: 1.0000 - val_loss: 0.0439 - val_acc: 0.9900
# Epoch 20/20
# 2807/2807 [==============================] - 13s 5ms/step - loss: 1.5004e-07 - acc: 1.0000 - val_loss: 0.0457 - val_acc: 0.9900
# 701/701 [==============================] - 1s 1ms/step
#
#
# 正解率= 0.9900142645699832 loss= 0.04565680805906066
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       174
#            1       0.99      0.99      0.99       179
#            2       0.98      0.99      0.99       168
#            3       0.99      0.98      0.98       179
#
#     accuracy                           0.99       700
#    macro avg       0.99      0.99      0.99       700
# weighted avg       0.99      0.99      0.99       700
# 処理時間：268.6641700267792[s]
#                                                 text true_label pre_label  \
# 0                    え？ホントかよ（笑） 合コン用語なる摩訶不思議な用語が話題に         IT       ライフ
# 1                    インタビュー：有森裕子「お互いに嘘は無い、それは確かなこと」         映画      スポーツ
# 2                      ナイナイ岡村、自分は破談するも「お見合い番組」で恋を応援         映画       ライフ
# 3     【オトナ女子映画部】あの時こうしていれば…“優柔不断女子”に贈る映画『ハーフ・デイズ』        ライフ        映画
# 4  【オトナ女子映画部】少女マンガ的な妄想ふくらむ“鉄板”ラブコメ『Black & Whit...        ライフ        映画
# 5                          セール価格で世界一住みやすい国オーストラリアへ！        ライフ        映画
# 6                             通話料金が安くなるスマホアプリが登場！        ライフ        IT
#
#    prediction
# 0    0.982795
# 1    0.963739
# 2    0.835669
# 3    0.968493
# 4    0.921999
# 5    0.706662
# 6    0.999916
